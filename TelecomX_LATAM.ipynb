# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
url_json = 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'

# %%
df = pd.read_json(url_json)

# %%
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df.shape
# Out:
# (7267, 6)

# %%
df.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df.iloc[0]
# Out:
# customerID                                           0002-ORFBO
# Churn                                                        No
# customer      {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# phone            {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# internet      {'InternetService': 'DSL', 'OnlineSecurity': '...
# account       {'Contract': 'One year', 'PaperlessBilling': '...
# Name: 0, dtype: object

# %%
df['customerID'].unique()
# Out:
# array(['0002-ORFBO', '0003-MKNFE', '0004-TLHLJ', ..., '9992-UJOEL',
#        '9993-LHIEB', '9995-HOTOH'], dtype=object)

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ##Nomalizando los datos JSON

# %% [markdown]
# ###Customer

# %%
df_customer_N = pd.json_normalize(df['customer'])

# %%
df_customer_N
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
df_customer_N.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 1467    Male              0      No         No       1
# 7196  Female              0     Yes        Yes       3
# 1243    Male              0     Yes        Yes      72
# 6646    Male              0     Yes         No      69
# 891   Female              1      No         No      27

# %%
df_customer_N.iloc[0]
# Out:
# gender           Female
# SeniorCitizen         0
# Partner             Yes
# Dependents          Yes
# tenure                9
# Name: 0, dtype: object

# %%
df_customer_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
df_customer_N.shape
# Out:
# (7267, 5)

# %%
df_customer_N.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure'], dtype='object')

# %%
#df_merged_customer = pd.concat([df_customer_N, df[['customerID', 'Churn']]], axis=1)
df_merged_customer = pd.concat([df[['customerID', 'Churn']], df_customer_N], axis = 1)

# %%
df_merged_customer
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
# [7267 rows x 7 columns]

# %%
df_merged_customer.dtypes
# Out:
# customerID       object
# Churn            object
# gender           object
# SeniorCitizen     int64
# Partner          object
# Dependents       object
# tenure            int64
# dtype: object

# %%
df_merged_customer.iloc[0]
# Out:
# customerID       0002-ORFBO
# Churn                    No
# gender               Female
# SeniorCitizen             0
# Partner                 Yes
# Dependents              Yes
# tenure                    9
# Name: 0, dtype: object

# %%
df_merged_customer['customerID'].unique()
# Out:
# array(['0002-ORFBO', '0003-MKNFE', '0004-TLHLJ', ..., '9992-UJOEL',
#        '9993-LHIEB', '9995-HOTOH'], dtype=object)

# %%
df_merged_customer['Churn'].unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %%
df_merged_customer['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df_merged_customer['SeniorCitizen'].unique()
# Out:
# array([0, 1])

# %%
df_merged_customer['Partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df_merged_customer['Dependents'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df_merged_customer['tenure'].unique()
# Out:
# array([ 9,  4, 13,  3, 71, 63,  7, 65, 54, 72,  5, 56, 34,  1, 45, 50, 23,
#        55, 26, 69, 11, 37, 49, 66, 67, 20, 43, 59, 12, 27,  2, 25, 29, 14,
#        35, 64, 39, 40,  6, 30, 70, 57, 58, 16, 32, 33, 10, 21, 61, 15, 44,
#        22, 24, 19, 47, 62, 46, 52,  8, 60, 48, 28, 41, 53, 68, 51, 31, 36,
#        17, 18, 38, 42,  0])

# %% [markdown]
# ###Phone

# %%
df_phone_N = pd.json_normalize(df['phone'])

# %%
df_phone_N
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
df_phone_N.head()
# Out:
#   PhoneService MultipleLines
# 0          Yes            No
# 1          Yes           Yes
# 2          Yes            No
# 3          Yes            No
# 4          Yes            No

# %%
df_phone_N.iloc[0]
# Out:
# PhoneService     Yes
# MultipleLines     No
# Name: 0, dtype: object

# %%
df_phone_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
df_phone_N.shape
# Out:
# (7267, 2)

# %%
df_phone_N.columns
# Out:
# Index(['PhoneService', 'MultipleLines'], dtype='object')

# %%
#df_merged_phone = pd.concat([df_phone_N, df[['customerID', 'Churn']]], axis=1)
df_merged_phone = pd.concat([df[['customerID', 'Churn']], df_phone_N], axis = 1)

# %%
df_merged_phone
# Out:
#       customerID Churn PhoneService     MultipleLines
# 0     0002-ORFBO    No          Yes                No
# 1     0003-MKNFE    No          Yes               Yes
# 2     0004-TLHLJ   Yes          Yes                No
# 3     0011-IGKFF   Yes          Yes                No
# 4     0013-EXCHZ   Yes          Yes                No
# ...          ...   ...          ...               ...
# 7262  9987-LUTYD    No          Yes                No
# 7263  9992-RRAMN   Yes          Yes               Yes
# 7264  9992-UJOEL    No          Yes                No
# 7265  9993-LHIEB    No          Yes                No
# 7266  9995-HOTOH    No           No  No phone service
#
# [7267 rows x 4 columns]

# %%
df_merged_phone.dtypes
# Out:
# customerID       object
# Churn            object
# PhoneService     object
# MultipleLines    object
# dtype: object

# %%
df_merged_phone.iloc[0]
# Out:
# customerID       0002-ORFBO
# Churn                    No
# PhoneService            Yes
# MultipleLines            No
# Name: 0, dtype: object

# %%
df_merged_phone['PhoneService'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df_merged_phone['MultipleLines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %% [markdown]
# ###Internet

# %%
df_internet_N = pd.json_normalize(df['internet'])

# %%
df_internet_N
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# 0            Yes              No
# 1             No             Yes
# 2             No              No
# 3            Yes             Yes
# 4            Yes              No
# ...          ...             ...
# 7262          No              No
# 7263          No             Yes
# 7264          No              No
# 7265          No             Yes
# 7266         Yes             Yes
#
# [7267 rows x 7 columns]

# %%
df_internet_N.tail()
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# 7262          No              No
# 7263          No             Yes
# 7264          No              No
# 7265          No             Yes
# 7266         Yes             Yes

# %%
df_internet_N.iloc[0]
# Out:
# InternetService     DSL
# OnlineSecurity       No
# OnlineBackup        Yes
# DeviceProtection     No
# TechSupport         Yes
# StreamingTV         Yes
# StreamingMovies      No
# Name: 0, dtype: object

# %%
df_internet_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB

# %%
df_internet_N.shape
# Out:
# (7267, 7)

# %%
df_internet_N.columns
# Out:
# Index(['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies'],
#       dtype='object')

# %%
#df_merged_internet = pd.concat([df_internet_N, df[['customerID', 'Churn']]], axis=1)
df_merged_internet = pd.concat([df[['customerID', 'Churn']], df_internet_N], axis = 1)

# %%
df_merged_internet
# Out:
#       customerID Churn InternetService OnlineSecurity OnlineBackup  \
# 0     0002-ORFBO    No             DSL             No          Yes
# 1     0003-MKNFE    No             DSL             No           No
# 2     0004-TLHLJ   Yes     Fiber optic             No           No
# 3     0011-IGKFF   Yes     Fiber optic             No          Yes
# 4     0013-EXCHZ   Yes     Fiber optic             No           No
# ...          ...   ...             ...            ...          ...
# 7262  9987-LUTYD    No             DSL            Yes           No
# 7263  9992-RRAMN   Yes     Fiber optic             No           No
# 7264  9992-UJOEL    No             DSL             No          Yes
# 7265  9993-LHIEB    No             DSL            Yes           No
# 7266  9995-HOTOH    No             DSL            Yes          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies
# 0                  No         Yes         Yes              No
# 1                  No          No          No             Yes
# 2                 Yes          No          No              No
# 3                 Yes          No         Yes             Yes
# 4                  No         Yes         Yes              No
# ...               ...         ...         ...             ...
# 7262               No         Yes          No              No
# 7263               No          No          No             Yes
# 7264               No          No          No              No
# 7265              Yes         Yes          No             Yes
# 7266              Yes          No         Yes             Yes
#
# [7267 rows x 9 columns]

# %%
df_merged_internet.dtypes
# Out:
# customerID          object
# Churn               object
# InternetService     object
# OnlineSecurity      object
# OnlineBackup        object
# DeviceProtection    object
# TechSupport         object
# StreamingTV         object
# StreamingMovies     object
# dtype: object

# %%
df_merged_internet.iloc[0]
# Out:
# customerID          0002-ORFBO
# Churn                       No
# InternetService            DSL
# OnlineSecurity              No
# OnlineBackup               Yes
# DeviceProtection            No
# TechSupport                Yes
# StreamingTV                Yes
# StreamingMovies             No
# Name: 0, dtype: object

# %%
df_merged_internet['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df_merged_internet['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df_merged_internet['OnlineBackup'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df_merged_internet['DeviceProtection'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df_merged_internet['TechSupport'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df_merged_internet['StreamingTV'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df_merged_internet['StreamingMovies'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %% [markdown]
# ###Account

# %%
df_account_N = pd.json_normalize(df['account'])

# %%
df_account_N
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# 3          1237.85
# 4            267.4
# ...            ...
# 7262         742.9
# 7263        1873.7
# 7264         92.75
# 7265       4627.65
# 7266        3707.6
#
# [7267 rows x 5 columns]

# %%
df_account_N.sample(5)
# Out:
#             Contract PaperlessBilling              PaymentMethod  \
# 43          Two year               No    Credit card (automatic)
# 5007        One year               No  Bank transfer (automatic)
# 5471  Month-to-month              Yes    Credit card (automatic)
# 4165  Month-to-month               No               Mailed check
# 2036  Month-to-month              Yes    Credit card (automatic)
#
#       Charges.Monthly Charges.Total
# 43               25.5         630.6
# 5007            100.0       1888.65
# 5471             69.1          3168
# 4165             19.6         93.45
# 2036             89.3       4016.85

# %%
df_account_N.iloc[0]
# Out:
# Contract                One year
# PaperlessBilling             Yes
# PaymentMethod       Mailed check
# Charges.Monthly             65.6
# Charges.Total              593.3
# Name: 0, dtype: object

# %%
df_account_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7267 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 284.0+ KB

# %%
df_account_N.shape
# Out:
# (7267, 5)

# %%
df_account_N.columns
# Out:
# Index(['Contract', 'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
#df_merged_account = pd.concat([df_account_N, df[['customerID', 'Churn']]], axis=1)
df_merged_account = pd.concat([df[['customerID', 'Churn']], df_account_N], axis = 1)

# %%
df_merged_account
# Out:
#       customerID Churn        Contract PaperlessBilling     PaymentMethod  \
# 0     0002-ORFBO    No        One year              Yes      Mailed check
# 1     0003-MKNFE    No  Month-to-month               No      Mailed check
# 2     0004-TLHLJ   Yes  Month-to-month              Yes  Electronic check
# 3     0011-IGKFF   Yes  Month-to-month              Yes  Electronic check
# 4     0013-EXCHZ   Yes  Month-to-month              Yes      Mailed check
# ...          ...   ...             ...              ...               ...
# 7262  9987-LUTYD    No        One year               No      Mailed check
# 7263  9992-RRAMN   Yes  Month-to-month              Yes  Electronic check
# 7264  9992-UJOEL    No  Month-to-month              Yes      Mailed check
# 7265  9993-LHIEB    No        Two year               No      Mailed check
# 7266  9995-HOTOH    No        Two year               No  Electronic check
#
#       Charges.Monthly Charges.Total
# 0               65.60         593.3
# 1               59.90         542.4
# 2               73.90        280.85
# 3               98.00       1237.85
# 4               83.90         267.4
# ...               ...           ...
# 7262            55.15         742.9
# 7263            85.10        1873.7
# 7264            50.30         92.75
# 7265            67.85       4627.65
# 7266            59.00        3707.6
#
# [7267 rows x 7 columns]

# %%
df_merged_account.dtypes
# Out:
# customerID           object
# Churn                object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# dtype: object

# %%
df_merged_account.iloc[0]
# Out:
# customerID            0002-ORFBO
# Churn                         No
# Contract                One year
# PaperlessBilling             Yes
# PaymentMethod       Mailed check
# Charges.Monthly             65.6
# Charges.Total              593.3
# Name: 0, dtype: object

# %%
df_merged_account['Contract'].unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
df_merged_account['PaperlessBilling'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df_merged_account['PaymentMethod'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Credit card (automatic)',
#        'Bank transfer (automatic)'], dtype=object)

# %%
df_merged_account['Charges.Monthly'].unique()
# Out:
# array([65.6 , 59.9 , 73.9 , ..., 91.75, 68.8 , 67.85])

# %%
df_merged_account['Charges.Total'].unique()
# Out:
# array(['593.3', '542.4', '280.85', ..., '742.9', '4627.65', '3707.6'],
#       dtype=object)

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
