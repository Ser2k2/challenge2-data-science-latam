# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
url_json = 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'

# %%
df = pd.read_json(url_json)

# %%
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df.shape
# Out:
# (7267, 6)

# %%
df.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
list(df.iloc[0])
# Out:
# ['0002-ORFBO',
#  'No',
#  {'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 9},
#  {'PhoneService': 'Yes', 'MultipleLines': 'No'},
#  {'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'No'},
#  {'Contract': 'One year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'Charges': {'Monthly': 65.6, 'Total': '593.3'}}]

# %%
df.isnull().sum()
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %% [markdown]
# ##Diccionario de datos

# %% [markdown]
# - `customerID`: número de identificación único de cada cliente
# - `Churn`: si el cliente dejó o no la empresa
# - `gender`: género (masculino y femenino)
# - `SeniorCitizen`: información sobre si un cliente tiene o no una edad igual o mayor a 65 años
# - `Partner`: si el cliente tiene o no una pareja
# - `Dependents`: si el cliente tiene o no dependientes
# - `tenure`: meses de contrato del cliente
# - `PhoneService`: suscripción al servicio telefónico
# - `MultipleLines`: suscripción a más de una línea telefónica
# - `InternetService`: suscripción a un proveedor de internet
# - `OnlineSecurity`: suscripción adicional de seguridad en línea
# - `OnlineBackup`: suscripción adicional de respaldo en línea
# - `DeviceProtection`: suscripción adicional de protección del dispositivo
# - `TechSupport`: suscripción adicional de soporte técnico, menor tiempo de espera
# - `StreamingTV`: suscripción de televisión por cable
# - `StreamingMovies`: suscripción de streaming de películas
# - `Contract`: tipo de contrato
# - `PaperlessBilling`: si el cliente prefiere recibir la factura en línea
# - `PaymentMethod`: forma de pago
# - `Charges.Monthly`: total de todos los servicios del cliente por mes
# - `Charges.Total`: total gastado por el cliente

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ##Columna CustomerID

# %%
df['customerID']
# Out:
# 0       0002-ORFBO
# 1       0003-MKNFE
# 2       0004-TLHLJ
# 3       0011-IGKFF
# 4       0013-EXCHZ
#            ...
# 7262    9987-LUTYD
# 7263    9992-RRAMN
# 7264    9992-UJOEL
# 7265    9993-LHIEB
# 7266    9995-HOTOH
# Name: customerID, Length: 7267, dtype: object

# %%
df['customerID'].head()
# Out:
# 0    0002-ORFBO
# 1    0003-MKNFE
# 2    0004-TLHLJ
# 3    0011-IGKFF
# 4    0013-EXCHZ
# Name: customerID, dtype: object

# %%
df['customerID'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: customerID
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
df['customer'].shape
# Out:
# (7267,)

# %%
df['customerID'].str.len()
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4       10
#         ..
# 7262    10
# 7263    10
# 7264    10
# 7265    10
# 7266    10
# Name: customerID, Length: 7267, dtype: int64

# %%
df['customerID'].str.len().value_counts(dropna=False)
# Out:
# customerID
# 10    7267
# Name: count, dtype: int64

# %%
df['customerID'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['customerID'].str.contains(r'\s', case=False).value_counts()
# Out:
# customerID
# False    7267
# Name: count, dtype: int64

# %% [markdown]
# ##Columna Churn

# %%
df['Churn']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7267, dtype: object

# %%
df['Churn'].sample(5)
# Out:
# 2051    No
# 13      No
# 459     No
# 2054    No
# 300     No
# Name: Churn, dtype: object

# %%
df['Churn'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Churn
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
df['Churn'].shape
# Out:
# (7267,)

# %% [markdown]
# Nota: Verificar el contenido de la columna 'Churn' por valores únicos.

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %%
df['Churn'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %%
(df['Churn'].str.len() == 0).sum()
# Out:
# np.int64(224)

# %%
df['Churn'].str.contains(r'^$|\s', case=False).value_counts()
# Out:
# Churn
# False    7043
# True      224
# Name: count, dtype: int64

# %%
df['Churn'].replace('', np.nan)
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7267, dtype: object

# %% [markdown]
# Nota: Guardando lo cambios en la columna 'Churn'y reemplazar el valor vació por 'nan'.

# %%
df['Churn'] = df['Churn'].replace('', np.nan)

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# Nota: Verificar de nuevo la columna 'Churn'.

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['Churn'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Churn
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
df['Churn'].shape[0]
# Out:
# 7267

# %%
df['Churn'].isnull().sum()
# Out:
# np.int64(224)

# %% [markdown]
# ##Nomalizando los datos JSON

# %% [markdown]
# ###Columna Customer

# %%
df_customer_N = pd.json_normalize(df['customer'])

# %%
df_customer_N
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
df_customer_N.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 1246  Female              1     Yes         No      72
# 1412    Male              0     Yes         No      33
# 3127    Male              1      No         No      37
# 3448    Male              0     Yes        Yes       1
# 5934  Female              0      No        Yes      43

# %%
df_customer_N.iloc[0]
# Out:
# gender           Female
# SeniorCitizen         0
# Partner             Yes
# Dependents          Yes
# tenure                9
# Name: 0, dtype: object

# %%
df_customer_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
df_customer_N.shape
# Out:
# (7267, 5)

# %%
df_customer_N.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure'], dtype='object')

# %%
df_customer_N.isnull().sum()
# Out:
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# tenure           0
# dtype: int64

# %%
(df_customer_N == '').sum()
# Out:
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# tenure           0
# dtype: int64

# %% [markdown]
# ####Columna Customer_genfer

# %%
df_customer_N['gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 7262    Female
# 7263      Male
# 7264      Male
# 7265      Male
# 7266      Male
# Name: gender, Length: 7267, dtype: object

# %%
df_customer_N['gender'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: gender
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
df_customer_N['gender'].shape
# Out:
# (7267,)

# %%
df_customer_N['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# ####Columna SeniorCitizen

# %%
df_customer_N['SeniorCitizen']
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 7262    0
# 7263    0
# 7264    0
# 7265    0
# 7266    0
# Name: SeniorCitizen, Length: 7267, dtype: int64

# %%
df_customer_N['SeniorCitizen'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: SeniorCitizen
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   int64
# dtypes: int64(1)
# memory usage: 56.9 KB

# %%
df_customer_N['SeniorCitizen'].shape
# Out:
# (7267,)

# %%
df_customer_N['SeniorCitizen'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ####Columna Partner

# %%
df_customer_N['Partner']
# Out:
# 0       Yes
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265    Yes
# 7266    Yes
# Name: Partner, Length: 7267, dtype: object

# %%
df_customer_N['Partner'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Partner
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
df_customer_N['Partner'].shape
# Out:
# (7267,)

# %%
df_customer_N['Partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# ####Columna Dependents

# %%
df_customer_N['Dependents']
# Out:
# 0       Yes
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7262     No
# 7263     No
# 7264     No
# 7265    Yes
# 7266    Yes
# Name: Dependents, Length: 7267, dtype: object

# %%
df_customer_N['Dependents'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Dependents
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
df_customer_N['Dependents'].shape
# Out:
# (7267,)

# %%
df_customer_N['Dependents'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# ####Convertir los datos 'Yes' y 'No' de las columnas Dependents y Columna Partner a 0 y 1

# %%
mapeo_si_no = {'Yes': 1, 'No': 0}

# %%
columnas_mapear_customerN = ['Dependents', 'Partner']

# %%
df_customer_N[columnas_mapear_customerN] = df_customer_N[columnas_mapear_customerN].apply(lambda col: col.map(mapeo_si_no))

# %%
df_customer_N
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure
# 0     Female              0        1           1       9
# 1       Male              0        0           0       9
# 2       Male              0        0           0       4
# 3       Male              1        1           0      13
# 4     Female              1        1           0       3
# ...      ...            ...      ...         ...     ...
# 7262  Female              0        0           0      13
# 7263    Male              0        1           0      22
# 7264    Male              0        0           0       2
# 7265    Male              0        1           1      67
# 7266    Male              0        1           1      63
#
# [7267 rows x 5 columns]

# %%
df_customer_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   int64
#  3   Dependents     7267 non-null   int64
#  4   tenure         7267 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 284.0+ KB

# %% [markdown]
# ####Columna tenure

# %%
df_customer_N['tenure']
# Out:
# 0        9
# 1        9
# 2        4
# 3       13
# 4        3
#         ..
# 7262    13
# 7263    22
# 7264     2
# 7265    67
# 7266    63
# Name: tenure, Length: 7267, dtype: int64

# %%
df_customer_N['tenure'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: tenure
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   int64
# dtypes: int64(1)
# memory usage: 56.9 KB

# %%
df_customer_N['tenure'].shape
# Out:
# (7267,)

# %%
df_customer_N['tenure'].unique()
# Out:
# array([ 9,  4, 13,  3, 71, 63,  7, 65, 54, 72,  5, 56, 34,  1, 45, 50, 23,
#        55, 26, 69, 11, 37, 49, 66, 67, 20, 43, 59, 12, 27,  2, 25, 29, 14,
#        35, 64, 39, 40,  6, 30, 70, 57, 58, 16, 32, 33, 10, 21, 61, 15, 44,
#        22, 24, 19, 47, 62, 46, 52,  8, 60, 48, 28, 41, 53, 68, 51, 31, 36,
#        17, 18, 38, 42,  0])

# %% [markdown]
# ###Phone

# %%
df_phone_N = pd.json_normalize(df['phone'])

# %%
df_phone_N
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
df_phone_N.head()
# Out:
#   PhoneService MultipleLines
# 0          Yes            No
# 1          Yes           Yes
# 2          Yes            No
# 3          Yes            No
# 4          Yes            No

# %%
df_phone_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
df_phone_N.shape
# Out:
# (7267, 2)

# %%
df_phone_N.columns
# Out:
# Index(['PhoneService', 'MultipleLines'], dtype='object')

# %%
df_phone_N.isnull().sum()
# Out:
# PhoneService     0
# MultipleLines    0
# dtype: int64

# %%
(df_phone_N == '').sum()
# Out:
# PhoneService     0
# MultipleLines    0
# dtype: int64

# %% [markdown]
# ####Columna PhoneService

# %%
df_phone_N['PhoneService']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262    Yes
# 7263    Yes
# 7264    Yes
# 7265    Yes
# 7266     No
# Name: PhoneService, Length: 7267, dtype: object

# %%
df_phone_N['PhoneService'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# #####Convertir los datos 'Yes' y 'No' de la Columna PhoneService a 0 y 1

# %%
df_phone_N['PhoneService'] = df_phone_N['PhoneService'].map(mapeo_si_no)

# %%
df_phone_N
# Out:
#       PhoneService     MultipleLines
# 0                1                No
# 1                1               Yes
# 2                1                No
# 3                1                No
# 4                1                No
# ...            ...               ...
# 7262             1                No
# 7263             1               Yes
# 7264             1                No
# 7265             1                No
# 7266             0  No phone service
#
# [7267 rows x 2 columns]

# %%
df_phone_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   int64
#  1   MultipleLines  7267 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 113.7+ KB

# %% [markdown]
# ####Columna MultipleLines

# %%
df_phone_N['MultipleLines']
# Out:
# 0                     No
# 1                    Yes
# 2                     No
# 3                     No
# 4                     No
#               ...
# 7262                  No
# 7263                 Yes
# 7264                  No
# 7265                  No
# 7266    No phone service
# Name: MultipleLines, Length: 7267, dtype: object

# %%
df_phone_N['MultipleLines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %% [markdown]
# ###Internet

# %%
df_internet_N = pd.json_normalize(df['internet'])

# %%
df_internet_N
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
df_internet_N.tail()
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# 7262          No              No
# 7263          No             Yes
# 7264          No              No
# 7265          No             Yes
# 7266         Yes             Yes

# %%
df_internet_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB

# %%
df_internet_N.shape
# Out:
# (7267, 7)

# %%
df_internet_N.columns
# Out:
# Index(['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies'],
#       dtype='object')

# %%
df_internet_N.isnull().sum()
# Out:
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %%
(df_internet_N == '').sum()
# Out:
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %% [markdown]
# ####Columna InternetService

# %%
df_internet_N['InternetService']
# Out:
# 0               DSL
# 1               DSL
# 2       Fiber optic
# 3       Fiber optic
# 4       Fiber optic
#            ...
# 7262            DSL
# 7263    Fiber optic
# 7264            DSL
# 7265            DSL
# 7266            DSL
# Name: InternetService, Length: 7267, dtype: object

# %%
df_internet_N['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %% [markdown]
# ####Columna OnlineSecurity

# %%
df_internet_N['OnlineSecurity']
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7262    Yes
# 7263     No
# 7264     No
# 7265    Yes
# 7266    Yes
# Name: OnlineSecurity, Length: 7267, dtype: object

# %%
df_internet_N['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %% [markdown]
# ####Columna OnlineBackup

# %%
df_internet_N['OnlineBackup']
# Out:
# 0       Yes
# 1        No
# 2        No
# 3       Yes
# 4        No
#        ...
# 7262     No
# 7263     No
# 7264    Yes
# 7265     No
# 7266    Yes
# Name: OnlineBackup, Length: 7267, dtype: object

# %%
df_internet_N['OnlineBackup'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %% [markdown]
# ####Columna DeviceProtection

# %%
df_internet_N['DeviceProtection']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 7262     No
# 7263     No
# 7264     No
# 7265    Yes
# 7266    Yes
# Name: DeviceProtection, Length: 7267, dtype: object

# %%
df_internet_N['DeviceProtection'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %% [markdown]
# ####Columna TechSupport

# %%
df_internet_N['TechSupport']
# Out:
# 0       Yes
# 1        No
# 2        No
# 3        No
# 4       Yes
#        ...
# 7262    Yes
# 7263     No
# 7264     No
# 7265    Yes
# 7266     No
# Name: TechSupport, Length: 7267, dtype: object

# %%
df_internet_N['TechSupport'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %% [markdown]
# ####Columna StreamingTV

# %%
df_internet_N['StreamingTV']
# Out:
# 0       Yes
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263     No
# 7264     No
# 7265     No
# 7266    Yes
# Name: StreamingTV, Length: 7267, dtype: object

# %%
df_internet_N['StreamingTV'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %% [markdown]
# ####Columna StreamingMovies

# %%
df_internet_N['StreamingMovies']
# Out:
# 0        No
# 1       Yes
# 2        No
# 3       Yes
# 4        No
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265    Yes
# 7266    Yes
# Name: StreamingMovies, Length: 7267, dtype: object

# %%
df_internet_N['StreamingMovies'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %% [markdown]
# ###Account

# %%
df_account_N = pd.json_normalize(df['account'])

# %%
df_account_N
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
df_account_N.sample(5)
# Out:
#             Contract PaperlessBilling              PaymentMethod  \
# 2500  Month-to-month              Yes           Electronic check
# 7055        Two year              Yes           Electronic check
# 4314  Month-to-month              Yes           Electronic check
# 1180  Month-to-month               No    Credit card (automatic)
# 937   Month-to-month               No  Bank transfer (automatic)
#
#       Charges.Monthly Charges.Total
# 2500            84.05        134.05
# 7055            97.20        6910.3
# 4314            72.80        930.05
# 1180            45.20           492
# 937             30.30        1380.1

# %%
df_account_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7267 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 284.0+ KB

# %%
df_account_N.shape
# Out:
# (7267, 5)

# %%
df_account_N.columns
# Out:
# Index(['Contract', 'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
df_account_N.isnull().sum()
# Out:
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
(df_account_N == '').sum()
# Out:
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %% [markdown]
# ####Columna Contract

# %%
df_account_N['Contract']
# Out:
# 0             One year
# 1       Month-to-month
# 2       Month-to-month
# 3       Month-to-month
# 4       Month-to-month
#              ...
# 7262          One year
# 7263    Month-to-month
# 7264    Month-to-month
# 7265          Two year
# 7266          Two year
# Name: Contract, Length: 7267, dtype: object

# %%
df_account_N['Contract'].unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %% [markdown]
# ####Columna PaperlessBilling

# %%
df_account_N['PaperlessBilling']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264    Yes
# 7265     No
# 7266     No
# Name: PaperlessBilling, Length: 7267, dtype: object

# %%
df_account_N['PaperlessBilling'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# #####Convertir los datos 'Yes' y 'No' de la Columna PaperlessBilling a 0 y 1

# %%
df_account_N['PaperlessBilling'] = df_account_N['PaperlessBilling'].map(mapeo_si_no)

# %%
df_account_N['PaperlessBilling']
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 7262    0
# 7263    1
# 7264    1
# 7265    0
# 7266    0
# Name: PaperlessBilling, Length: 7267, dtype: int64

# %% [markdown]
# ####Columna PaymentMethod

# %%
df_account_N['PaymentMethod']
# Out:
# 0           Mailed check
# 1           Mailed check
# 2       Electronic check
# 3       Electronic check
# 4           Mailed check
#               ...
# 7262        Mailed check
# 7263    Electronic check
# 7264        Mailed check
# 7265        Mailed check
# 7266    Electronic check
# Name: PaymentMethod, Length: 7267, dtype: object

# %%
df_account_N['PaymentMethod'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Credit card (automatic)',
#        'Bank transfer (automatic)'], dtype=object)

# %% [markdown]
# ####Columna Charges.Monthly

# %%
df_account_N['Charges.Monthly']
# Out:
# 0       65.60
# 1       59.90
# 2       73.90
# 3       98.00
# 4       83.90
#         ...
# 7262    55.15
# 7263    85.10
# 7264    50.30
# 7265    67.85
# 7266    59.00
# Name: Charges.Monthly, Length: 7267, dtype: float64

# %%
df_account_N['Charges.Monthly'].isnull().sum()
# Out:
# np.int64(0)

# %%
(df_account_N['Charges.Monthly'] == '').value_counts()
# Out:
# Charges.Monthly
# False    7267
# Name: count, dtype: int64

# %% [markdown]
# ####Columna Charges.Total

# %%
df_account_N['Charges.Total']
# Out:
# 0         593.3
# 1         542.4
# 2        280.85
# 3       1237.85
# 4         267.4
#          ...
# 7262      742.9
# 7263     1873.7
# 7264      92.75
# 7265    4627.65
# 7266     3707.6
# Name: Charges.Total, Length: 7267, dtype: object

# %%
df_account_N['Charges.Total'].str.isspace().sum()
# Out:
# np.int64(11)

# %%
df_account_N['Charges.Total'].str.contains(r'^$|\s', case=False).value_counts()
# Out:
# Charges.Total
# False    7256
# True       11
# Name: count, dtype: int64

# %%
df_account_N['Charges.Total'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Replace empty strings (' ') with NaN in the 'Charges.Total' column
df_account_N['Charges.Total'] = df_account_N['Charges.Total'].replace(' ', np.nan)

# %%
# Now, convert the 'Charges.Total' column to float64.
# The values that were originally ' ' are now NaN and can be handled by astype.
df_account_N['Charges.Total'] = df_account_N['Charges.Total'].astype(np.float64)

# %%
df_account_N['Charges.Total']
# Out:
# 0        593.30
# 1        542.40
# 2        280.85
# 3       1237.85
# 4        267.40
#          ...
# 7262     742.90
# 7263    1873.70
# 7264      92.75
# 7265    4627.65
# 7266    3707.60
# Name: Charges.Total, Length: 7267, dtype: float64

# %%
df_account_N['Charges.Total'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Charges.Total
# Non-Null Count  Dtype
# --------------  -----
# 7256 non-null   float64
# dtypes: float64(1)
# memory usage: 56.9 KB

# %%
df_account_N['Charges.Total'].isna().sum()
# Out:
# np.int64(11)

# %%
df_account_N
# Out:
#             Contract  PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year                 1      Mailed check            65.60
# 1     Month-to-month                 0      Mailed check            59.90
# 2     Month-to-month                 1  Electronic check            73.90
# 3     Month-to-month                 1  Electronic check            98.00
# 4     Month-to-month                 1      Mailed check            83.90
# ...              ...               ...               ...              ...
# 7262        One year                 0      Mailed check            55.15
# 7263  Month-to-month                 1  Electronic check            85.10
# 7264  Month-to-month                 1      Mailed check            50.30
# 7265        Two year                 0      Mailed check            67.85
# 7266        Two year                 0  Electronic check            59.00
#
#       Charges.Total
# 0            593.30
# 1            542.40
# ...

# %% [markdown]
# ####Columna Cuentas.Diarias

# %%
df_account_N['Cuentas.Diarias'] = (df_account_N['Charges.Monthly'] / 30).round(2)

# %%
df_account_N
# Out:
#             Contract  PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year                 1      Mailed check            65.60
# 1     Month-to-month                 0      Mailed check            59.90
# 2     Month-to-month                 1  Electronic check            73.90
# 3     Month-to-month                 1  Electronic check            98.00
# 4     Month-to-month                 1      Mailed check            83.90
# ...              ...               ...               ...              ...
# 7262        One year                 0      Mailed check            55.15
# 7263  Month-to-month                 1  Electronic check            85.10
# 7264  Month-to-month                 1      Mailed check            50.30
# 7265        Two year                 0      Mailed check            67.85
# 7266        Two year                 0  Electronic check            59.00
#
#       Charges.Total  Cuentas.Diarias
# 0            593.30             2.19
# ...

# %%
df_account_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   int64
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7256 non-null   float64
#  5   Cuentas.Diarias   7267 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 340.8+ KB

# %% [markdown]
# ##Unir las tablas en un a sola tabla

# %%
df_M = pd.concat([df[['customerID', 'Churn']], df_customer_N, df_phone_N, df_internet_N,df_account_N], axis = 1)

# %%
df_M
# Out:
#       customerID Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0        1           1       9
# 1     0003-MKNFE    No    Male              0        0           0       9
# 2     0004-TLHLJ   Yes    Male              0        0           0       4
# 3     0011-IGKFF   Yes    Male              1        1           0      13
# 4     0013-EXCHZ   Yes  Female              1        1           0       3
# ...          ...   ...     ...            ...      ...         ...     ...
# 7262  9987-LUTYD    No  Female              0        0           0      13
# 7263  9992-RRAMN   Yes    Male              0        1           0      22
# 7264  9992-UJOEL    No    Male              0        0           0       2
# 7265  9993-LHIEB    No    Male              0        1           1      67
# 7266  9995-HOTOH    No    Male              0        1           1      63
#
# ...

# %%
df_M.columns.tolist()
# Out:
# ['customerID',
#  'Churn',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Charges.Monthly',
#  'Charges.Total',
#  'Cuentas.Diarias']

# %% [markdown]
# ##Cambiar el nombre de las columnas

# %%
nuevos_nombres = {
    'customerID': 'ID_Cliente',
    'Churn': 'Abandono_Servicio', # 'Abandono' o 'Fuga_Cliente' también funcionarían
    'gender': 'Genero',
    'SeniorCitizen': 'Ciudadano_Senior', # ¿Es un adulto mayor?
    'Partner': 'Tiene_Pareja', # ¿Tiene pareja?
    'Dependents': 'Tiene_Dependientes', # ¿Tiene dependientes?
    'tenure': 'Antiguedad_Meses', # Antigüedad en meses
    'PhoneService': 'Servicio_Telefono', # ¿Tiene servicio telefónico?
    'MultipleLines': 'Multiples_Lineas', # ¿Tiene múltiples líneas?
    'InternetService': 'Tipo_Servicio_Internet', # Tipo de servicio de internet
    'OnlineSecurity': 'Seguridad_Online', # ¿Tiene seguridad en línea?
    'OnlineBackup': 'Copia_Seguridad_Online', # ¿Tiene copia de seguridad en línea?
    'DeviceProtection': 'Proteccion_Dispositivo', # ¿Tiene protección de dispositivo?
    'TechSupport': 'Soporte_Tecnico', # ¿Tiene soporte técnico?
    'StreamingTV': 'Streaming_TV', # ¿Tiene servicio de streaming de TV?
    'StreamingMovies': 'Streaming_Peliculas', # ¿Tiene servicio de streaming de películas?
    'Contract': 'Tipo_Contrato', # Tipo de contrato
    'PaperlessBilling': 'Facturacion_Sin_Papel', # Facturación sin papel
    'PaymentMethod': 'Metodo_Pago', # Método de pago
    'Charges.Monthly': 'Cargos_Mensuales', # Cargos mensuales en USD
    'Charges.Total': 'Cargos_Totales', # Cargos totales en USD
    # 'Cuentas.Diarias' ya está bien, la dejamos tal cual o la incluimos si queremos renombrar
    'Cuentas.Diarias': 'Cuentas_Diarias' # Por si quieres especificar
    }

# %%
df_M.rename(columns=nuevos_nombres, inplace=True)

# %%
df_M
# Out:
#       ID_Cliente Abandono_Servicio  Genero  Ciudadano_Senior  Tiene_Pareja  \
# 0     0002-ORFBO                No  Female                 0             1
# 1     0003-MKNFE                No    Male                 0             0
# 2     0004-TLHLJ               Yes    Male                 0             0
# 3     0011-IGKFF               Yes    Male                 1             1
# 4     0013-EXCHZ               Yes  Female                 1             1
# ...          ...               ...     ...               ...           ...
# 7262  9987-LUTYD                No  Female                 0             0
# 7263  9992-RRAMN               Yes    Male                 0             1
# 7264  9992-UJOEL                No    Male                 0             0
# 7265  9993-LHIEB                No    Male                 0             1
# 7266  9995-HOTOH                No    Male                 0             1
#
#       Tiene_Dependientes  Antiguedad_Meses  Servicio_Telefono  \
# ...

# %%
df_M.columns.tolist()
# Out:
# ['ID_Cliente',
#  'Abandono_Servicio',
#  'Genero',
#  'Ciudadano_Senior',
#  'Tiene_Pareja',
#  'Tiene_Dependientes',
#  'Antiguedad_Meses',
#  'Servicio_Telefono',
#  'Multiples_Lineas',
#  'Tipo_Servicio_Internet',
#  'Seguridad_Online',
#  'Copia_Seguridad_Online',
#  'Proteccion_Dispositivo',
#  'Soporte_Tecnico',
#  'Streaming_TV',
#  'Streaming_Peliculas',
#  'Tipo_Contrato',
#  'Facturacion_Sin_Papel',
#  'Metodo_Pago',
#  'Cargos_Mensuales',
#  'Cargos_Totales',
#  'Cuentas_Diarias']

# %%
df_M.shape
# Out:
# (7267, 22)

# %% [markdown]
# ##Informacion Duplicada

# %%
df_M.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##Valores Faltantes

# %%
df_M.isnull().sum()
# Out:
# ID_Cliente                  0
# Abandono_Servicio         224
# Genero                      0
# Ciudadano_Senior            0
# Tiene_Pareja                0
# Tiene_Dependientes          0
# Antiguedad_Meses            0
# Servicio_Telefono           0
# Multiples_Lineas            0
# Tipo_Servicio_Internet      0
# Seguridad_Online            0
# Copia_Seguridad_Online      0
# Proteccion_Dispositivo      0
# Soporte_Tecnico             0
# Streaming_TV                0
# Streaming_Peliculas         0
# Tipo_Contrato               0
# Facturacion_Sin_Papel       0
# Metodo_Pago                 0
# Cargos_Mensuales            0
# Cargos_Totales             11
# Cuentas_Diarias             0
# dtype: int64

# %%
df_M.isnull().sum().sum()
# Out:
# np.int64(235)

# %%
df_M.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID_Cliente              7267 non-null   object
#  1   Abandono_Servicio       7043 non-null   object
#  2   Genero                  7267 non-null   object
#  3   Ciudadano_Senior        7267 non-null   int64
#  4   Tiene_Pareja            7267 non-null   int64
#  5   Tiene_Dependientes      7267 non-null   int64
#  6   Antiguedad_Meses        7267 non-null   int64
#  7   Servicio_Telefono       7267 non-null   int64
#  8   Multiples_Lineas        7267 non-null   object
#  9   Tipo_Servicio_Internet  7267 non-null   object
#  10  Seguridad_Online        7267 non-null   object
#  11  Copia_Seguridad_Online  7267 non-null   object
#  12  Proteccion_Dispositivo  7267 non-null   object
#  13  Soporte_Tecnico         7267 non-null   object
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
df_M.head()
# Out:
#    ID_Cliente Abandono_Servicio  Genero  Ciudadano_Senior  Tiene_Pareja  \
# 0  0002-ORFBO                No  Female                 0             1
# 1  0003-MKNFE                No    Male                 0             0
# 2  0004-TLHLJ               Yes    Male                 0             0
# 3  0011-IGKFF               Yes    Male                 1             1
# 4  0013-EXCHZ               Yes  Female                 1             1
#
#    Tiene_Dependientes  Antiguedad_Meses  Servicio_Telefono Multiples_Lineas  \
# 0                   1                 9                  1               No
# 1                   0                 9                  1              Yes
# 2                   0                 4                  1               No
# 3                   0                13                  1               No
# 4                   0                 3                  1               No
#
#   Tipo_Servicio_Internet  ... Proteccion_Dispositivo Soporte_Tecnico  \
# ...

# %%
df_M.describe()
# Out:
#        Ciudadano_Senior  Tiene_Pareja  Tiene_Dependientes  Antiguedad_Meses  \
# count       7267.000000   7267.000000         7267.000000       7267.000000
# mean           0.162653      0.484106            0.300124         32.346498
# std            0.369074      0.499782            0.458343         24.571773
# min            0.000000      0.000000            0.000000          0.000000
# 25%            0.000000      0.000000            0.000000          9.000000
# 50%            0.000000      0.000000            0.000000         29.000000
# 75%            0.000000      1.000000            1.000000         55.000000
# max            1.000000      1.000000            1.000000         72.000000
#
#        Servicio_Telefono  Facturacion_Sin_Papel  Cargos_Mensuales  \
# count        7267.000000            7267.000000       7267.000000
# mean            0.902711               0.593230         64.720098
# std             0.296371               0.491265         30.129572
# ...

# %% [markdown]
# ##Distribución de evasión

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Abandono_Servicio', data=df_M)
plt.title('Figura 1: Distribución de Abandono de Servicio')
plt.xlabel('Abandono de Servicio (0=No, 1=Sí)')
plt.ylabel('Número de Clientes')
plt.xticks([0, 1], ['No Abandona', 'Abandona'])
plt.show()

# %% [markdown]
# Esta gráfica muestra claramente la distribución de clientes que abandonaron el servicio versus los que no. Confirma la desbalance de clases, con un número mucho mayor de clientes que no abandonan.
#
# Sirve como una excelente introducción visual a la magnitud del problema de churn.

# %%
plt.figure(figsize=(6, 6))
df_M['Abandono_Servicio'].value_counts(normalize=True).plot.pie(autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Figura 2: Porcentaje de Abandono de Servicio')
plt.ylabel('')
plt.show()

# %% [markdown]
# Este gráfico de pastel es aún más directo en comunicar la tasa de abandono global: 26.5% de los clientes han abandonado. Esto es una tasa significativa y justifica plenamente la necesidad de este proyecto.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df_M, x='Antiguedad_Meses', hue='Abandono_Servicio', multiple='stack', bins=30)
plt.title('Figura 3: Distribución de Antigüedad por Abandono de Servicio')
plt.xlabel('Antigüedad en Meses')
plt.ylabel('Número de Clientes')
plt.legend(title='Abandono', labels=['No', 'Sí'])
plt.show()

# %% [markdown]
# Esta imágen confirma8 que la mayoría de los clientes que abandonan son nuevos clientes (pico en los primeros meses). Hay una gran cantidad de abandonos en el primer mes y durante los primeros 10-20 meses. Los clientes con mayor antigüedad (cercano a 70 meses) tienen una tasa de abandono relativamente menor.

# %% [markdown]
# ##Conteo de evasión por variables numéricas

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df_M, x='Cargos_Totales', hue='Abandono_Servicio',
             multiple='stack', bins=40, kde=True, palette='coolwarm')
plt.title('Figura 4: Histograma de Cargos Totales por Estado de Abandono')
plt.xlabel('Cargos Totales (USD)')
plt.ylabel('Número de Clientes')
plt.legend(title='Abandono', labels=['No Abandona', 'Abandona'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Este histograma muestra que la distribución de Cargos_Totales es muy diferente para los clientes que abandonan. Los clientes que abandonan tienen una concentración mucho mayor en Cargos Totales bajos. Esto es lógico, ya que los clientes con menor antigüedad (que son los que más abandonan) habrán acumulado menos cargos totales.

# %%
plt.figure(figsize=(8, 7))

sns.boxplot(x='Abandono_Servicio', y='Cargos_Totales', hue='Abandono_Servicio',
            data=df_M, palette='viridis', legend=False)

plt.title('Figura 5: Box Plot de Cargos Totales por Estado de Abandono')
plt.xlabel('Abandono de Servicio (0 = No Abandona, 1 = Abandona)')
plt.ylabel('Cargos Totales (USD)')
plt.xticks([0, 1], ['No Abandona', 'Abandona'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# El box plot lo hace aún más visual: la mediana de Cargos_Totales para los clientes que abandonan es significativamente menor que para los que no abandonan. La dispersión (IQR) también es menor para los clientes que abandonan. Esto subraya que el churn es un problema más prevalente entre los clientes que no han generado muchos ingresos totales a la empresa.

# %%
plt.figure(figsize=(10, 6))

sns.kdeplot(data=df_M, x='Cargos_Totales', hue='Abandono_Servicio',
            fill=True, common_norm=False, palette='mako')

plt.title('Figura 6: Densidad de Cargos Totales por Estado de Abandono')
plt.xlabel('Cargos Totales (USD)')
plt.ylabel('Densidad')
plt.legend(title='Abandono', labels=['No Abandona', 'Abandona'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
#  Similar a los histogramas y boxplots, este gráfico de densidad muestra la distribución de Cargos_Totales de forma suavizada. Confirma que la densidad de clientes que abandonan es mucho mayor en los rangos de Cargos_Totales bajos.

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=df_M, x='Antiguedad_Meses', hue='Abandono_Servicio',
             multiple='stack', bins=30, kde=True, palette='coolwarm')

plt.title('Figura 7: Histograma de Antigüedad por Estado de Abandono')
plt.xlabel('Antigüedad en Meses')
plt.ylabel('Número de Clientes')
plt.legend(title='Abandono', labels=['No Abandona', 'Abandona'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Su comportamiento es similar a la grafico de Distribución de Antigüedad por Abandono de Servicio.

# %%
plt.figure(figsize=(8, 7))

sns.boxplot(x='Abandono_Servicio', y='Antiguedad_Meses', hue='Abandono_Servicio',
            data=df_M, palette='viridis', legend=False)
plt.title('Figura 8: Box Plot de Antigüedad en Meses por Estado de Abandono')
plt.xlabel('Abandono de Servicio (0 = No Abandona, 1 = Abandona)')
plt.ylabel('Antigüedad en Meses')
plt.xticks([0, 1], ['No Abandona', 'Abandona'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Este box plot visualiza de manera muy efectiva lo que ya se insinuaba: los clientes que abandonan tienen una Antiguedad_Meses considerablemente menor (la mediana está alrededor de 10 meses), mientras que los clientes que no abandonan tienen una antigüedad mucho mayor (mediana alrededor de 35-40 meses).

# %%
plt.figure(figsize=(10, 6))

sns.kdeplot(data=df_M, x='Antiguedad_Meses', hue='Abandono_Servicio',
            fill=True, common_norm=False, palette='mako')

plt.title('Figura 9: Densidad de Antigüedad por Estado de Abandono')
plt.xlabel('Antigüedad en Meses')
plt.ylabel('Densidad')
plt.legend(title='Abandono', labels=['No Abandona', 'Abandona'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Este gráfico de densidad refuerza el hallazgo del box plot y histograma. La curva de densidad para los clientes que abandonan tiene un pico muy pronunciado en los primeros meses, mientras que la curva para los clientes que no abandonan es más extendida hacia la derecha, con un segundo pico en la antigüedad alta, confirmando la lealtad de los clientes veteranos.

# %% [markdown]
# ##Recuento de evasión por variables categóricas

# %%
conteo_abandono_genero = df_M.groupby('Genero')['Abandono_Servicio'].value_counts().unstack(fill_value=0)

# %%
conteo_abandono_genero
# Out:
# Abandono_Servicio    No  Yes
# Genero
# Female             2549  939
# Male               2625  930

# %%
conteo_abandono_genero.columns
# Out:
# Index(['No', 'Yes'], dtype='object', name='Abandono_Servicio')

# %%
tasa_abandono_genero = conteo_abandono_genero.apply(lambda x: x['Yes'] / (x['No'] + x['Yes']) * 100, axis=1)

# %%
tasa_abandono_genero
# Out:
# Genero
# Female    26.920872
# Male      26.160338
# dtype: float64

# %%
plot_df_tasa = tasa_abandono_genero.reset_index(name='Tasa_Abandono')

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.barplot(x='Genero', y='Tasa_Abandono', hue='Genero', data=plot_df_tasa, palette='viridis', legend=False, ax=axes[0])
axes[0].set_title('Figura 10: Tasa de Abandono de Servicio por Género (%)')
axes[0].set_xlabel('Género')
axes[0].set_ylabel('Porcentaje de Abandono (%)')
axes[0].set_ylim(0, 100)
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Añadir los valores en la parte superior de las barras
for index, value in enumerate(plot_df_tasa['Tasa_Abandono']):
    axes[0].text(index, value + 2, f'{value:.2f}%', ha='center', va='bottom', fontsize=10)

sns.countplot(x='Genero', hue='Abandono_Servicio', data=df_M, palette='pastel', ax=axes[1])
axes[1].set_title('Figura 11: Número de Clientes por Género y Estado de Abandono')
axes[1].set_xlabel('Género')
axes[1].set_ylabel('Número de Clientes')
axes[1].legend(title='Abandono', labels=['No Abandona', 'Abandona'])
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
#  Tasa de Abandono de Servicio por Género (%): esta gráfica es muy clara y, como se anticipó, muestra que no hay una diferencia significativa en la tasa de abandono entre hombres y mujeres (aproximadamente 26.92% para mujeres y 26.16% para hombres).

# %% [markdown]
# Número de Clientes por Género y Estado de Abandono: Este gráfico complementa al anterior mostrando las cantidades absolutas. Aunque el número total de clientes es ligeramente mayor en el grupo "Male", la proporción de "Abandona" y "No Abandona" dentro de cada género es muy parecida, lo que visualmente apoya la conclusión de que el género no influye en la tasa de abandono.

# %%
conteo_abandono_contrato = df_M.groupby('Tipo_Contrato')['Abandono_Servicio'].value_counts().unstack(fill_value=0)

# %%
conteo_abandono_contrato
# Out:
# Abandono_Servicio    No   Yes
# Tipo_Contrato
# Month-to-month     2220  1655
# One year           1307   166
# Two year           1647    48

# %%
tasa_abandono_contrato = conteo_abandono_contrato.apply(lambda x: x['Yes'] / (x['No'] + x['Yes']) * 100, axis=1)

# %%
tasa_abandono_contrato
# Out:
# Tipo_Contrato
# Month-to-month    42.709677
# One year          11.269518
# Two year           2.831858
# dtype: float64

# %%
plot_df_tasa_contrato = tasa_abandono_contrato.reset_index(name='Tasa_Abandono')

fig, axes = plt.subplots(1, 2, figsize=(18, 7))

sns.barplot(x='Tipo_Contrato', y='Tasa_Abandono', hue='Tipo_Contrato',
            data=plot_df_tasa_contrato, palette='viridis', legend=False, ax=axes[0])
axes[0].set_title('Figura 12: Tasa de Abandono de Servicio por Tipo de Contrato (%)')
axes[0].set_xlabel('Tipo de Contrato')
axes[0].set_ylabel('Porcentaje de Abandono (%)')
axes[0].set_ylim(0, 100)
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Añadir los valores en la parte superior de las barras
for index, value in enumerate(plot_df_tasa_contrato['Tasa_Abandono']):
    axes[0].text(index, value + 2, f'{value:.2f}%', ha='center', va='bottom', fontsize=10)

sns.countplot(x='Tipo_Contrato', hue='Abandono_Servicio', data=df_M, palette='pastel', ax=axes[1])
axes[1].set_title('Figura 13: Número de Clientes por Tipo de Contrato y Estado de Abandono')
axes[1].set_xlabel('Tipo de Contrato')
axes[1].set_ylabel('Número de Clientes')
axes[1].legend(title='Abandono', labels=['No Abandona', 'Abandona'])
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# Tasa de Abandono de Servicio por Tipo de Contrato:  ¡Este es un hallazgo crítico! La tasa de abandono para los clientes con contrato "Month-to-month" (mensual) es extremadamente alta (42.71%). En contraste, los contratos de "One year" (un año) tienen una tasa de 11.27% y los de "Two year" (dos años) una tasa muy baja de 2.83%. Esto es un indicador muy fuerte de que el tipo de contrato es un factor determinante en el abandono.

# %% [markdown]
# Número de Clientes por Tipo de Contrato y Estado de Abandono:  Este gráfico de barras apiladas muestra las cantidades absolutas. Aunque hay un gran número de clientes con contrato "Month-to-month" que no abandonan, el volumen de clientes que sí abandonan en esta categoría es abrumadoramente el más alto. Para los contratos de "One year" y "Two year", la cantidad de abandonos es mínima en comparación con los clientes que permanecen.

# %%
conteo_abandono_pago = df_M.groupby('Metodo_Pago')['Abandono_Servicio'].value_counts().unstack(fill_value=0)

# %%
conteo_abandono_pago
# Out:
# Abandono_Servicio            No   Yes
# Metodo_Pago
# Bank transfer (automatic)  1286   258
# Credit card (automatic)    1290   232
# Electronic check           1294  1071
# Mailed check               1304   308

# %%
tasa_abandono_pago = conteo_abandono_pago.apply(lambda x: x['Yes'] / (x['No'] + x['Yes']) * 100, axis=1)

# %%
tasa_abandono_pago
# Out:
# Metodo_Pago
# Bank transfer (automatic)    16.709845
# Credit card (automatic)      15.243101
# Electronic check             45.285412
# Mailed check                 19.106700
# dtype: float64

# %%
plot_df_tasa_pago = tasa_abandono_pago.reset_index(name='Tasa_Abandono')

# Ordenar las categorías para que el gráfico sea más legible (opcional, pero recomendado)
orden_metodo_pago = [
    'Electronic check',
    'Mailed check',
    'Bank transfer (automatic)',
    'Credit card (automatic)'
]
plot_df_tasa_pago['Metodo_Pago'] = pd.Categorical(
    plot_df_tasa_pago['Metodo_Pago'],
    categories=orden_metodo_pago,
    ordered=True
)
plot_df_tasa_pago = plot_df_tasa_pago.sort_values('Metodo_Pago')

fig, axes = plt.subplots(1, 2, figsize=(20, 7))

sns.barplot(x='Metodo_Pago', y='Tasa_Abandono', hue='Metodo_Pago',
            data=plot_df_tasa_pago, palette='coolwarm', legend=False, ax=axes[0])
axes[0].set_title('Figura 14: Tasa de Abandono de Servicio por Método de Pago (%)')
axes[0].set_xlabel('Método de Pago')
axes[0].set_ylabel('Porcentaje de Abandono (%)')
axes[0].set_ylim(0, 100)

axes[0].tick_params(axis='x', rotation=0)
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

for index, value in enumerate(plot_df_tasa_pago['Tasa_Abandono']):
    axes[0].text(index, value + 2, f'{value:.2f}%', ha='center', va='bottom', fontsize=10)


sns.countplot(x='Metodo_Pago', hue='Abandono_Servicio', data=df_M, palette='pastel', ax=axes[1],
              order=orden_metodo_pago) # Usar el mismo orden para consistencia

axes[1].set_title('Figura 15: Número de Clientes por Método de Pago y Estado de Abandono')
axes[1].set_xlabel('Método de Pago')
axes[1].set_ylabel('Número de Clientes')
axes[1].legend(title='Abandono', labels=['No Abandona', 'Abandona'])

axes[1].tick_params(axis='x', rotation=0)
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# Tasa de Abandono de Servicio por Método de Pago: Otro hallazgo crucial. Los clientes que utilizan "Electronic check" (cheque electrónico) como método de pago tienen una tasa de abandono significativamente más alta (45.29%) en comparación con otros métodos. Los métodos de pago automáticos (transferencia bancaria y tarjeta de crédito) y el cheque por correo tienen tasas de abandono mucho más bajas (entre 15% y 19%).

# %% [markdown]
#  Número de Clientes por Método de Pago y Estado de Abandono:
#
# Este gráfico de barras agrupadas visualiza la distribución de clientes que abandonan y no abandonan para cada método de pago.
#
#  * Para "Electronic check", aunque hay un gran número de clientes que no abandonan, el volumen absoluto de clientes que SÍ abandonan es el más alto entre todos los métodos de pago. Esto refuerza el insight del grafico de Tasa de Abandono de Servicio por Método de Pago de que este es un método de pago de alto riesgo, no solo en porcentaje sino también en la cantidad real de clientes afectados.
#
# * Para los otros métodos (Mailed check, Bank transfer (automatic), Credit card (automatic)), el número de clientes que no abandonan es considerablemente mayor que los que sí abandonan, y el volumen absoluto de abandonos es mucho menor en comparación con "Electronic check".

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ##Resumen Ejecutivo

# %% [markdown]
# Telecom X enfrenta un desafío significativo con una tasa de abandono (churn) de clientes del 26.5%, como se observa claramente en la Figura 2 (img_02.png). Este informe detalla los hallazgos clave de un Análisis Exploratorio de Datos (EDA) basado directamente en las visualizaciones generadas, con el objetivo de identificar los patrones y factores que impulsan esta evasión.
#
# Los resultados visuales destacan que los principales impulsores del abandono son la baja antigüedad del cliente, el tipo de contrato mensual y el uso del cheque electrónico como método de pago. Estos factores se manifiestan en patrones claros de abandono que requieren atención estratégica inmediata.

# %% [markdown]
# ## Metodología

# %% [markdown]
# Se realizó un Análisis Exploratorio de Datos (EDA) sobre el DataFrame df_M de 7267 filas y 22 columnas. La metodología incluyó:
#
# * Limpieza de Datos: Identificación y tratamiento de valores nulos.
#
# * Análisis Descriptivo: Resumen estadístico y distribución de variables.
#
# * Visualizaciones Estratégicas: Creación de gráficos para identificar patrones y tendencias entre las características del cliente y el "Abandono_Servicio".

# %% [markdown]
# ##Hallazgos Clave Basados en Visualizaciones

# %% [markdown]
# ###Visión General del Abandono

# %% [markdown]
# Figura 1: Distribución de Abandono de Servicio
#
# * Resultado: Este gráfico de barras inicial muestra el conteo absoluto de clientes. Hay aproximadamente 5200 clientes que 'No Abandona' y alrededor de 1800 que 'Abandona'. Esto indica una clara desproporción entre las clases, siendo 'No Abandona' la clase mayoritaria.
# * Insight: La empresa tiene una base de clientes leales, pero el volumen de abandono es considerable.

# %% [markdown]
# Figura 2: Porcentaje de Abandono de Servicio
#
# * Resultado: Un gráfico circular que cuantifica la proporción de abandono. El 73.5% de los clientes 'No Abandona' y el 26.5% 'Abandona'.
# * Insight: Casi un tercio de los clientes de Telecom X abandonan el servicio, lo que subraya la magnitud del problema y la urgencia de su abordaje.

# %% [markdown]
# ###Factores Clave Relacionados con el Abandono

# %% [markdown]
# Figuras 3 y 7: Distribución/Histograma de Antigüedad por Abandono de Servicio
#
# * Resultado: Ambos histogramas, uno apilado y otro superpuesto, muestran la frecuencia de clientes por antigüedad (en meses) diferenciando por estado de abandono. Se observa un pico muy alto de abandonos (barras naranjas) en los primeros meses de antigüedad (0 a 5 meses). A medida que la antigüedad aumenta, el volumen de abandonos disminuye drásticamente, con la mayoría de los clientes con alta antigüedad (más de 60 meses) siendo "No Abandona".
# * Insight: Los clientes son más propensos a abandonar el servicio en las etapas iniciales de su relación con Telecom X. La lealtad parece aumentar significativamente con el tiempo de permanencia.

# %% [markdown]
# Figura 8: Box Plot de Antigüedad en Meses por Estado de Abandono
#
# * Resultado: Este box plot compara la distribución de Antiguedad_Meses para clientes que abandonan y no abandonan. La caja para 'Abandona' está ubicada en un rango de antigüedad muy bajo (mediana alrededor de 10 meses), mientras que la caja para 'No Abandona' se extiende a antigüedades mucho mayores (mediana alrededor de 35-40 meses).
# * Insight: Confirma visualmente que los clientes que abandonan son predominantemente aquellos con una corta historia en la empresa.

# %% [markdown]
# Figura 9: Densidad de Antigüedad por Estado de Abandono
#
# * Resultado: Un gráfico de densidad que suaviza las distribuciones de antigüedad. La curva de densidad para 'Abandona' muestra un pico pronunciado y estrecho en los valores de antigüedad más bajos, mientras que la curva para 'No Abandona' es más dispersa y se extiende hacia antigüedades más altas, con un segundo pico hacia los 70 meses.
# * Insight: Proporciona una clara visualización de que la mayor concentración de riesgo de abandono se encuentra en los primeros meses de servicio.

# %% [markdown]
# Figura 4: Histograma de Cargos Totales por Estado de Abandono
#
# * Resultado: Este histograma superpuesto muestra que la distribución de Cargos_Totales para los clientes que 'Abandona' está fuertemente concentrada en los rangos de cargos más bajos (cerca de $0 a $1000), mientras que la distribución para 'No Abandona' se extiende a cargos totales mucho más altos.
# * Insight: Los clientes que abandonan han generado menos ingresos totales para la empresa, lo cual es coherente con su baja antigüedad.

# %% [markdown]
# Figura 5: Box Plot de Cargos Totales por Estado de Abandono
#
# * Resultado: El box plot compara la distribución de Cargos_Totales. La caja de 'mAbandona' tiene una mediana y un rango intercuartílico considerablemente más bajos que la caja de 'No Abandona', que muestra una mediana y dispersión mucho mayores.
# * mInsight: Reafirma que los clientes con bajos cargos totales acumulados (lo que implica baja antigüedad) son más propensos a abandonar.

# %% [markdown]
# Figura 6: Densidad de Cargos Totales por Estado de Abandono
#
# * Resultado: Similar al histograma, este gráfico de densidad muestra una densidad mucho mayor para 'Abandona' en el rango de bajos Cargos_Totales, con una curva que cae rápidamente. La curva para 'No Abandona' tiene una distribución más amplia hacia valores más altos.
# * Insight: Los clientes con menor gasto acumulado a lo largo del tiempo tienen una mayor probabilidad de abandono.

# %% [markdown]
# Figura 10: Tasa de Abandono de Servicio por Género (%)
# * Resultado: Este gráfico de barras porcentual muestra una tasa de abandono del 26.92% para 'Female' y 26.16% para 'Male'.
# * Insight: No hay una diferencia sustancial en la tasa de abandono entre géneros, lo que sugiere que el género no es un factor determinante en el churn.

# %% [markdown]
# Figura 11: Número de Clientes por Género y Estado de Abandono
#
# * Resultado: Un gráfico de barras agrupadas que muestra los conteos absolutos. La proporción de clientes que 'Abandona' y 'No Abandona' es visualmente muy similar para ambos géneros, aunque el total de clientes masculinos es ligeramente superior.
# * Insight: Refuerza la conclusión de que el género no es un factor discriminante clave en la propensión al abandono

# %% [markdown]
# Figura 12: Tasa de Abandono de Servicio por Tipo de Contrato (%)
# * Resultado: ¡Este es un hallazgo crítico! La tasa de abandono es del 42.71% para contratos 'Month-to-month', cayendo drásticamente a 11.27% para 'One year' y a un mínimo de 2.83% para 'Two year'.
# * Insight: El tipo de contrato es el predictor más potente del abandono. Los contratos mensuales presentan un riesgo de churn extremadamente alto, mientras que los contratos a largo plazo demuestran una lealtad considerablemente mayor.

# %% [markdown]
# Figura 13: Número de Clientes por Tipo de Contrato y Estado de Abandono
#
# * Resultado: Este gráfico de barras agrupadas muestra las cantidades absolutas. Aunque hay un gran número de clientes mensuales que no abandonan, el volumen de abandonos en la categoría 'Month-to-month' es abrumadoramente el más alto en comparación con los otros tipos de contrato.
# * Insight: La magnitud del problema de abandono está concentrada en los clientes con contratos mensuales, tanto en porcentaje como en número absoluto.

# %% [markdown]
# Figura 14: Tasa de Abandono de Servicio por Método de Pago (%)
#
# * Resultado: Otro hallazgo crítico. La tasa de abandono es del 45.29% para 'Electronic check', siendo significativamente más alta que para 'Mailed check' (19.11%), 'Bank transfer (automatic)' (16.71%) y 'Credit card (automatic)' (15.24%).
# * Insight: El método de pago 'Electronic check' es un fuerte indicador de alto riesgo de abandono.

# %% [markdown]
# Figura 15: Número de Clientes por Método de Pago y Estado de Abandono
#
# * Resultado: Este gráfico de barras agrupadas muestra los conteos absolutos. Para 'Electronic check', el número de clientes que 'Abandona' es notablemente el más alto en comparación con los otros métodos de pago, a pesar de que la cantidad de clientes que 'No Abandona' en esta categoría es también alta.
# * Insight: Refuerza que el 'Electronic check' no solo tiene la mayor tasa de abandono porcentual, sino que también afecta al mayor volumen de clientes.

# %% [markdown]
# ##Conclusiones y Recomendaciones Preliminares

# %% [markdown]
# ###Conclusiones

# %% [markdown]
# Los resultados directos de las visualizaciones revelan que los principales impulsores del abandono de clientes en Telecom X son:
#
# * Antigüedad del Cliente: Los clientes nuevos (<10 meses) son los más propensos a abandonar, representando el pico principal de churn (Figuras 3, 7, 8, 9).
# * Tipo de Contrato: Los contratos 'Month-to-month' (mensuales) son la categoría de mayor riesgo, con una tasa de abandono del 42.71% y el mayor volumen absoluto de churn (Figuras 12 y 13).
# * Método de Pago: El 'Electronic check' está fuertemente correlacionado con el abandono, presentando la tasa más alta (45.29%) y el mayor número de abandonos (Figuras 14 y 15).
# * Cargos Totales: Los clientes que abandonan tienen cargos totales acumulados significativamente más bajos, lo cual es un reflejo de su menor antigüedad (Figuras 4, 5, 6).

# %% [markdown]
# ###Recomendaciones

# %% [markdown]
# Foco Urgente en la Retención de Clientes Mensuales:
#
# Priorizar la implementación de programas agresivos de incentivos (ej., descuentos por permanencia, beneficios adicionales) para migrar a clientes con contratos 'Month-to-month' hacia planes de 'One year' o 'Two year'. La Figura 12 y Figura 13 demuestran que esta es la estrategia con mayor potencial para reducir el churn masivo.

# %% [markdown]
# Revisión y Optimización del Proceso de 'Electronic Check':
#
# Investigar a fondo las razones detrás de la altísima tasa de abandono asociada al 'Electronic check'. Esto podría implicar una auditoría de la usabilidad de la plataforma de pago, problemas técnicos, o percepciones de seguridad. La Figura 14 y Figura 15 exigen una acción inmediata en este método de pago.

# %% [markdown]
# Reforzar la Experiencia del Cliente Nuevo:
#
# Desarrollar un programa de incorporación robusto y un seguimiento proactivo para los clientes durante sus primeros meses (especialmente los primeros 10-15 meses). Las Figuras 3, 7, 8 y 9 señalan que la mayor fuga ocurre en este período crítico, por lo que una atención especial puede mejorar la retención temprana.

# %% [markdown]
# Análisis de Cargos Mensuales y Totales:
#
# Aunque no directamente visualizado en estos gráficos, los patrones en Cargos_Totales (Figuras 4, 5, 6) sugieren una correlación con la antigüedad y el valor del cliente. Futuras investigaciones podrían explorar si los clientes con cargos mensuales altos (que suelen ser los de fibra óptica) son más propensos al churn, ya que esto no se abordó completamente aquí pero fue un insight del EDA previo.
