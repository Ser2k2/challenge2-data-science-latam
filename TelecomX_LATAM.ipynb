# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
url_json = 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'

# %%
df = pd.read_json(url_json)

# %%
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df.shape
# Out:
# (7267, 6)

# %%
df.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
list(df.iloc[0])
# Out:
# ['0002-ORFBO',
#  'No',
#  {'gender': 'Female',
#   'SeniorCitizen': 0,
#   'Partner': 'Yes',
#   'Dependents': 'Yes',
#   'tenure': 9},
#  {'PhoneService': 'Yes', 'MultipleLines': 'No'},
#  {'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'Yes',
#   'StreamingTV': 'Yes',
#   'StreamingMovies': 'No'},
#  {'Contract': 'One year',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Mailed check',
#   'Charges': {'Monthly': 65.6, 'Total': '593.3'}}]

# %%
df.isnull().sum()
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %% [markdown]
# ##Diccionario de datos

# %% [markdown]
# - `customerID`: número de identificación único de cada cliente
# - `Churn`: si el cliente dejó o no la empresa
# - `gender`: género (masculino y femenino)
# - `SeniorCitizen`: información sobre si un cliente tiene o no una edad igual o mayor a 65 años
# - `Partner`: si el cliente tiene o no una pareja
# - `Dependents`: si el cliente tiene o no dependientes
# - `tenure`: meses de contrato del cliente
# - `PhoneService`: suscripción al servicio telefónico
# - `MultipleLines`: suscripción a más de una línea telefónica
# - `InternetService`: suscripción a un proveedor de internet
# - `OnlineSecurity`: suscripción adicional de seguridad en línea
# - `OnlineBackup`: suscripción adicional de respaldo en línea
# - `DeviceProtection`: suscripción adicional de protección del dispositivo
# - `TechSupport`: suscripción adicional de soporte técnico, menor tiempo de espera
# - `StreamingTV`: suscripción de televisión por cable
# - `StreamingMovies`: suscripción de streaming de películas
# - `Contract`: tipo de contrato
# - `PaperlessBilling`: si el cliente prefiere recibir la factura en línea
# - `PaymentMethod`: forma de pago
# - `Charges.Monthly`: total de todos los servicios del cliente por mes
# - `Charges.Total`: total gastado por el cliente

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ##Columna CustomerID

# %%
df['customerID']
# Out:
# 0       0002-ORFBO
# 1       0003-MKNFE
# 2       0004-TLHLJ
# 3       0011-IGKFF
# 4       0013-EXCHZ
#            ...
# 7262    9987-LUTYD
# 7263    9992-RRAMN
# 7264    9992-UJOEL
# 7265    9993-LHIEB
# 7266    9995-HOTOH
# Name: customerID, Length: 7267, dtype: object

# %%
df['customerID'].head()
# Out:
# 0    0002-ORFBO
# 1    0003-MKNFE
# 2    0004-TLHLJ
# 3    0011-IGKFF
# 4    0013-EXCHZ
# Name: customerID, dtype: object

# %%
df['customerID'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: customerID
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
df['customer'].shape
# Out:
# (7267,)

# %%
df['customerID'].str.len()
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4       10
#         ..
# 7262    10
# 7263    10
# 7264    10
# 7265    10
# 7266    10
# Name: customerID, Length: 7267, dtype: int64

# %%
df['customerID'].str.len().value_counts(dropna=False)
# Out:
# customerID
# 10    7267
# Name: count, dtype: int64

# %%
df['customerID'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['customerID'].str.contains(r'\s', case=False).value_counts()
# Out:
# customerID
# False    7267
# Name: count, dtype: int64

# %% [markdown]
# ##Columna Churn

# %%
df['Churn']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7267, dtype: object

# %%
df['Churn'].sample(5)
# Out:
# 6711    Yes
# 6947     No
# 5012     No
# 7107     No
# 5973     No
# Name: Churn, dtype: object

# %%
df['Churn'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Churn
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
df['Churn'].shape
# Out:
# (7267,)

# %% [markdown]
# Nota: Verificar el contenido de la columna 'Churn' por valores únicos.

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %%
df['Churn'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %%
(df['Churn'].str.len() == 0).sum()
# Out:
# np.int64(224)

# %%
df['Churn'].str.contains(r'^$|\s', case=False).value_counts()
# Out:
# Churn
# False    7043
# True      224
# Name: count, dtype: int64

# %%
df['Churn'].replace('', np.nan)
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7267, dtype: object

# %% [markdown]
# Nota: Guardando lo cambios en la columna 'Churn'y reemplazar el valor vació por 'nan'.

# %%
df['Churn'] = df['Churn'].replace('', np.nan)

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# Nota: Verificar de nuevo la columna 'Churn'.

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['Churn'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Churn
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
df['Churn'].shape[0]
# Out:
# 7267

# %%
df['Churn'].isnull().sum()
# Out:
# np.int64(224)

# %% [markdown]
# ##Nomalizando los datos JSON

# %% [markdown]
# ###Columna Customer

# %%
df_customer_N = pd.json_normalize(df['customer'])

# %%
df_customer_N
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
df_customer_N.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 5132    Male              0      No        Yes      55
# 652   Female              0      No         No      13
# 5437  Female              0      No         No      48
# 4603  Female              0     Yes         No      71
# 4955    Male              1      No         No      46

# %%
df_customer_N.iloc[0]
# Out:
# gender           Female
# SeniorCitizen         0
# Partner             Yes
# Dependents          Yes
# tenure                9
# Name: 0, dtype: object

# %%
df_customer_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
df_customer_N.shape
# Out:
# (7267, 5)

# %%
df_customer_N.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure'], dtype='object')

# %%
df_customer_N.isnull().sum()
# Out:
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# tenure           0
# dtype: int64

# %%
(df_customer_N == '').sum()
# Out:
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# tenure           0
# dtype: int64

# %% [markdown]
# ####Columna Customer_genfer

# %%
df_customer_N['gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 7262    Female
# 7263      Male
# 7264      Male
# 7265      Male
# 7266      Male
# Name: gender, Length: 7267, dtype: object

# %%
df_customer_N['gender'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: gender
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
df_customer_N['gender'].shape
# Out:
# (7267,)

# %%
df_customer_N['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# ####Columna SeniorCitizen

# %%
df_customer_N['SeniorCitizen']
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 7262    0
# 7263    0
# 7264    0
# 7265    0
# 7266    0
# Name: SeniorCitizen, Length: 7267, dtype: int64

# %%
df_customer_N['SeniorCitizen'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: SeniorCitizen
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   int64
# dtypes: int64(1)
# memory usage: 56.9 KB

# %%
df_customer_N['SeniorCitizen'].shape
# Out:
# (7267,)

# %%
df_customer_N['SeniorCitizen'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ####Columna Partner

# %%
df_customer_N['Partner']
# Out:
# 0       Yes
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265    Yes
# 7266    Yes
# Name: Partner, Length: 7267, dtype: object

# %%
df_customer_N['Partner'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Partner
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
df_customer_N['Partner'].shape
# Out:
# (7267,)

# %%
df_customer_N['Partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# ####Columna Dependents

# %%
df_customer_N['Dependents']
# Out:
# 0       Yes
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7262     No
# 7263     No
# 7264     No
# 7265    Yes
# 7266    Yes
# Name: Dependents, Length: 7267, dtype: object

# %%
df_customer_N['Dependents'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Dependents
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
df_customer_N['Dependents'].shape
# Out:
# (7267,)

# %%
df_customer_N['Dependents'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# ####Convertir los datos 'Yes' y 'No' de las columnas Dependents y Columna Partner a 0 y 1

# %%
mapeo_si_no = {'Yes': 1, 'No': 0}

# %%
columnas_mapear_customerN = ['Dependents', 'Partner']

# %%
df_customer_N[columnas_mapear_customerN] = df_customer_N[columnas_mapear_customerN].apply(lambda col: col.map(mapeo_si_no))

# %%
df_customer_N
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure
# 0     Female              0        1           1       9
# 1       Male              0        0           0       9
# 2       Male              0        0           0       4
# 3       Male              1        1           0      13
# 4     Female              1        1           0       3
# ...      ...            ...      ...         ...     ...
# 7262  Female              0        0           0      13
# 7263    Male              0        1           0      22
# 7264    Male              0        0           0       2
# 7265    Male              0        1           1      67
# 7266    Male              0        1           1      63
#
# [7267 rows x 5 columns]

# %%
df_customer_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   int64
#  3   Dependents     7267 non-null   int64
#  4   tenure         7267 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 284.0+ KB

# %% [markdown]
# ####Columna tenure

# %%
df_customer_N['tenure']
# Out:
# 0        9
# 1        9
# 2        4
# 3       13
# 4        3
#         ..
# 7262    13
# 7263    22
# 7264     2
# 7265    67
# 7266    63
# Name: tenure, Length: 7267, dtype: int64

# %%
df_customer_N['tenure'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: tenure
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   int64
# dtypes: int64(1)
# memory usage: 56.9 KB

# %%
df_customer_N['tenure'].shape
# Out:
# (7267,)

# %%
df_customer_N['tenure'].unique()
# Out:
# array([ 9,  4, 13,  3, 71, 63,  7, 65, 54, 72,  5, 56, 34,  1, 45, 50, 23,
#        55, 26, 69, 11, 37, 49, 66, 67, 20, 43, 59, 12, 27,  2, 25, 29, 14,
#        35, 64, 39, 40,  6, 30, 70, 57, 58, 16, 32, 33, 10, 21, 61, 15, 44,
#        22, 24, 19, 47, 62, 46, 52,  8, 60, 48, 28, 41, 53, 68, 51, 31, 36,
#        17, 18, 38, 42,  0])

# %% [markdown]
# ###Phone

# %%
df_phone_N = pd.json_normalize(df['phone'])

# %%
df_phone_N
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
df_phone_N.head()
# Out:
#   PhoneService MultipleLines
# 0          Yes            No
# 1          Yes           Yes
# 2          Yes            No
# 3          Yes            No
# 4          Yes            No

# %%
df_phone_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
df_phone_N.shape
# Out:
# (7267, 2)

# %%
df_phone_N.columns
# Out:
# Index(['PhoneService', 'MultipleLines'], dtype='object')

# %%
df_phone_N.isnull().sum()
# Out:
# PhoneService     0
# MultipleLines    0
# dtype: int64

# %%
(df_phone_N == '').sum()
# Out:
# PhoneService     0
# MultipleLines    0
# dtype: int64

# %% [markdown]
# ####Columna PhoneService

# %%
df_phone_N['PhoneService']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262    Yes
# 7263    Yes
# 7264    Yes
# 7265    Yes
# 7266     No
# Name: PhoneService, Length: 7267, dtype: object

# %%
df_phone_N['PhoneService'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# #####Convertir los datos 'Yes' y 'No' de la Columna PhoneService a 0 y 1

# %%
df_phone_N['PhoneService'] = df_phone_N['PhoneService'].map(mapeo_si_no)

# %%
df_phone_N
# Out:
#       PhoneService     MultipleLines
# 0                1                No
# 1                1               Yes
# 2                1                No
# 3                1                No
# 4                1                No
# ...            ...               ...
# 7262             1                No
# 7263             1               Yes
# 7264             1                No
# 7265             1                No
# 7266             0  No phone service
#
# [7267 rows x 2 columns]

# %%
df_phone_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   int64
#  1   MultipleLines  7267 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 113.7+ KB

# %% [markdown]
# ####Columna MultipleLines

# %%
df_phone_N['MultipleLines']
# Out:
# 0                     No
# 1                    Yes
# 2                     No
# 3                     No
# 4                     No
#               ...
# 7262                  No
# 7263                 Yes
# 7264                  No
# 7265                  No
# 7266    No phone service
# Name: MultipleLines, Length: 7267, dtype: object

# %%
df_phone_N['MultipleLines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %% [markdown]
# ###Internet

# %%
df_internet_N = pd.json_normalize(df['internet'])

# %%
df_internet_N
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
df_internet_N.tail()
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# 7262          No              No
# 7263          No             Yes
# 7264          No              No
# 7265          No             Yes
# 7266         Yes             Yes

# %%
df_internet_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB

# %%
df_internet_N.shape
# Out:
# (7267, 7)

# %%
df_internet_N.columns
# Out:
# Index(['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies'],
#       dtype='object')

# %%
df_internet_N.isnull().sum()
# Out:
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %%
(df_internet_N == '').sum()
# Out:
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %% [markdown]
# ####Columna InternetService

# %%
df_internet_N['InternetService']
# Out:
# 0               DSL
# 1               DSL
# 2       Fiber optic
# 3       Fiber optic
# 4       Fiber optic
#            ...
# 7262            DSL
# 7263    Fiber optic
# 7264            DSL
# 7265            DSL
# 7266            DSL
# Name: InternetService, Length: 7267, dtype: object

# %%
df_internet_N['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %% [markdown]
# ####Columna OnlineSecurity

# %%
df_internet_N['OnlineSecurity']
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7262    Yes
# 7263     No
# 7264     No
# 7265    Yes
# 7266    Yes
# Name: OnlineSecurity, Length: 7267, dtype: object

# %%
df_internet_N['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %% [markdown]
# ####Columna OnlineBackup

# %%
df_internet_N['OnlineBackup']
# Out:
# 0       Yes
# 1        No
# 2        No
# 3       Yes
# 4        No
#        ...
# 7262     No
# 7263     No
# 7264    Yes
# 7265     No
# 7266    Yes
# Name: OnlineBackup, Length: 7267, dtype: object

# %%
df_internet_N['OnlineBackup'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %% [markdown]
# ####Columna DeviceProtection

# %%
df_internet_N['DeviceProtection']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 7262     No
# 7263     No
# 7264     No
# 7265    Yes
# 7266    Yes
# Name: DeviceProtection, Length: 7267, dtype: object

# %%
df_internet_N['DeviceProtection'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %% [markdown]
# ####Columna TechSupport

# %%
df_internet_N['TechSupport']
# Out:
# 0       Yes
# 1        No
# 2        No
# 3        No
# 4       Yes
#        ...
# 7262    Yes
# 7263     No
# 7264     No
# 7265    Yes
# 7266     No
# Name: TechSupport, Length: 7267, dtype: object

# %%
df_internet_N['TechSupport'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %% [markdown]
# ####Columna StreamingTV

# %%
df_internet_N['StreamingTV']
# Out:
# 0       Yes
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263     No
# 7264     No
# 7265     No
# 7266    Yes
# Name: StreamingTV, Length: 7267, dtype: object

# %%
df_internet_N['StreamingTV'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %% [markdown]
# ####Columna StreamingMovies

# %%
df_internet_N['StreamingMovies']
# Out:
# 0        No
# 1       Yes
# 2        No
# 3       Yes
# 4        No
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265    Yes
# 7266    Yes
# Name: StreamingMovies, Length: 7267, dtype: object

# %%
df_internet_N['StreamingMovies'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %% [markdown]
# ###Account

# %%
df_account_N = pd.json_normalize(df['account'])

# %%
df_account_N
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
df_account_N.sample(5)
# Out:
#             Contract PaperlessBilling            PaymentMethod  \
# 3967  Month-to-month              Yes             Mailed check
# 5360        One year               No         Electronic check
# 6537        Two year              Yes         Electronic check
# 3254  Month-to-month               No         Electronic check
# 2128        Two year              Yes  Credit card (automatic)
#
#       Charges.Monthly Charges.Total
# 3967            59.65        638.95
# 5360            19.60        411.15
# 6537           118.65        8477.6
# 3254            19.25         112.3
# 2128           104.90       7732.65

# %%
df_account_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7267 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 284.0+ KB

# %%
df_account_N.shape
# Out:
# (7267, 5)

# %%
df_account_N.columns
# Out:
# Index(['Contract', 'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
df_account_N.isnull().sum()
# Out:
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
(df_account_N == '').sum()
# Out:
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %% [markdown]
# ####Columna Contract

# %%
df_account_N['Contract']
# Out:
# 0             One year
# 1       Month-to-month
# 2       Month-to-month
# 3       Month-to-month
# 4       Month-to-month
#              ...
# 7262          One year
# 7263    Month-to-month
# 7264    Month-to-month
# 7265          Two year
# 7266          Two year
# Name: Contract, Length: 7267, dtype: object

# %%
df_account_N['Contract'].unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %% [markdown]
# ####Columna PaperlessBilling

# %%
df_account_N['PaperlessBilling']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264    Yes
# 7265     No
# 7266     No
# Name: PaperlessBilling, Length: 7267, dtype: object

# %%
df_account_N['PaperlessBilling'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# #####Convertir los datos 'Yes' y 'No' de la Columna PaperlessBilling a 0 y 1

# %%
df_account_N['PaperlessBilling'] = df_account_N['PaperlessBilling'].map(mapeo_si_no)

# %%
df_account_N['PaperlessBilling']
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 7262    0
# 7263    1
# 7264    1
# 7265    0
# 7266    0
# Name: PaperlessBilling, Length: 7267, dtype: int64

# %% [markdown]
# ####Columna PaymentMethod

# %%
df_account_N['PaymentMethod']
# Out:
# 0           Mailed check
# 1           Mailed check
# 2       Electronic check
# 3       Electronic check
# 4           Mailed check
#               ...
# 7262        Mailed check
# 7263    Electronic check
# 7264        Mailed check
# 7265        Mailed check
# 7266    Electronic check
# Name: PaymentMethod, Length: 7267, dtype: object

# %%
df_account_N['PaymentMethod'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Credit card (automatic)',
#        'Bank transfer (automatic)'], dtype=object)

# %% [markdown]
# ####Columna Charges.Monthly

# %%
df_account_N['Charges.Monthly']
# Out:
# 0       65.60
# 1       59.90
# 2       73.90
# 3       98.00
# 4       83.90
#         ...
# 7262    55.15
# 7263    85.10
# 7264    50.30
# 7265    67.85
# 7266    59.00
# Name: Charges.Monthly, Length: 7267, dtype: float64

# %%
df_account_N['Charges.Monthly'].isnull().sum()
# Out:
# np.int64(0)

# %%
(df_account_N['Charges.Monthly'] == '').value_counts()
# Out:
# Charges.Monthly
# False    7267
# Name: count, dtype: int64

# %% [markdown]
# ####Columna Charges.Total

# %%
df_account_N['Charges.Total']
# Out:
# 0         593.3
# 1         542.4
# 2        280.85
# 3       1237.85
# 4         267.4
#          ...
# 7262      742.9
# 7263     1873.7
# 7264      92.75
# 7265    4627.65
# 7266     3707.6
# Name: Charges.Total, Length: 7267, dtype: object

# %%
df_account_N['Charges.Total'].str.isspace().sum()
# Out:
# np.int64(11)

# %%
df_account_N['Charges.Total'].str.contains(r'^$|\s', case=False).value_counts()
# Out:
# Charges.Total
# False    7256
# True       11
# Name: count, dtype: int64

# %%
df_account_N['Charges.Total'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Replace empty strings (' ') with NaN in the 'Charges.Total' column
df_account_N['Charges.Total'] = df_account_N['Charges.Total'].replace(' ', np.nan)

# %%
# Now, convert the 'Charges.Total' column to float64.
# The values that were originally ' ' are now NaN and can be handled by astype.
df_account_N['Charges.Total'] = df_account_N['Charges.Total'].astype(np.float64)

# %%
df_account_N['Charges.Total']
# Out:
# 0        593.30
# 1        542.40
# 2        280.85
# 3       1237.85
# 4        267.40
#          ...
# 7262     742.90
# 7263    1873.70
# 7264      92.75
# 7265    4627.65
# 7266    3707.60
# Name: Charges.Total, Length: 7267, dtype: float64

# %%
df_account_N['Charges.Total'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Charges.Total
# Non-Null Count  Dtype
# --------------  -----
# 7256 non-null   float64
# dtypes: float64(1)
# memory usage: 56.9 KB

# %%
df_account_N['Charges.Total'].isna().sum()
# Out:
# np.int64(11)

# %%
df_account_N
# Out:
#             Contract  PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year                 1      Mailed check            65.60
# 1     Month-to-month                 0      Mailed check            59.90
# 2     Month-to-month                 1  Electronic check            73.90
# 3     Month-to-month                 1  Electronic check            98.00
# 4     Month-to-month                 1      Mailed check            83.90
# ...              ...               ...               ...              ...
# 7262        One year                 0      Mailed check            55.15
# 7263  Month-to-month                 1  Electronic check            85.10
# 7264  Month-to-month                 1      Mailed check            50.30
# 7265        Two year                 0      Mailed check            67.85
# 7266        Two year                 0  Electronic check            59.00
#
#       Charges.Total
# 0            593.30
# 1            542.40
# ...

# %% [markdown]
# ####Columna Cuentas.Diarias

# %%
df_account_N['Cuentas.Diarias'] = (df_account_N['Charges.Monthly'] / 30).round(2)

# %%
df_account_N
# Out:
#             Contract  PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year                 1      Mailed check            65.60
# 1     Month-to-month                 0      Mailed check            59.90
# 2     Month-to-month                 1  Electronic check            73.90
# 3     Month-to-month                 1  Electronic check            98.00
# 4     Month-to-month                 1      Mailed check            83.90
# ...              ...               ...               ...              ...
# 7262        One year                 0      Mailed check            55.15
# 7263  Month-to-month                 1  Electronic check            85.10
# 7264  Month-to-month                 1      Mailed check            50.30
# 7265        Two year                 0      Mailed check            67.85
# 7266        Two year                 0  Electronic check            59.00
#
#       Charges.Total  Cuentas.Diarias
# 0            593.30             2.19
# ...

# %%
df_account_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   int64
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7256 non-null   float64
#  5   Cuentas.Diarias   7267 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 340.8+ KB

# %% [markdown]
# ##Unir las tablas en un a sola tabla

# %%
df_M = pd.concat([df[['customerID', 'Churn']], df_customer_N, df_phone_N, df_internet_N,df_account_N], axis = 1)

# %%
df_M
# Out:
#       customerID Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0        1           1       9
# 1     0003-MKNFE    No    Male              0        0           0       9
# 2     0004-TLHLJ   Yes    Male              0        0           0       4
# 3     0011-IGKFF   Yes    Male              1        1           0      13
# 4     0013-EXCHZ   Yes  Female              1        1           0       3
# ...          ...   ...     ...            ...      ...         ...     ...
# 7262  9987-LUTYD    No  Female              0        0           0      13
# 7263  9992-RRAMN   Yes    Male              0        1           0      22
# 7264  9992-UJOEL    No    Male              0        0           0       2
# 7265  9993-LHIEB    No    Male              0        1           1      67
# 7266  9995-HOTOH    No    Male              0        1           1      63
#
# ...

# %%
df_M.columns.tolist()
# Out:
# ['customerID',
#  'Churn',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Charges.Monthly',
#  'Charges.Total',
#  'Cuentas.Diarias']

# %% [markdown]
# ##Cambiar el nombre de las columnas

# %%
nuevos_nombres = {
    'customerID': 'ID_Cliente',
    'Churn': 'Abandono_Servicio', # 'Abandono' o 'Fuga_Cliente' también funcionarían
    'gender': 'Genero',
    'SeniorCitizen': 'Ciudadano_Senior', # ¿Es un adulto mayor?
    'Partner': 'Tiene_Pareja', # ¿Tiene pareja?
    'Dependents': 'Tiene_Dependientes', # ¿Tiene dependientes?
    'tenure': 'Antiguedad_Meses', # Antigüedad en meses
    'PhoneService': 'Servicio_Telefono', # ¿Tiene servicio telefónico?
    'MultipleLines': 'Multiples_Lineas', # ¿Tiene múltiples líneas?
    'InternetService': 'Tipo_Servicio_Internet', # Tipo de servicio de internet
    'OnlineSecurity': 'Seguridad_Online', # ¿Tiene seguridad en línea?
    'OnlineBackup': 'Copia_Seguridad_Online', # ¿Tiene copia de seguridad en línea?
    'DeviceProtection': 'Proteccion_Dispositivo', # ¿Tiene protección de dispositivo?
    'TechSupport': 'Soporte_Tecnico', # ¿Tiene soporte técnico?
    'StreamingTV': 'Streaming_TV', # ¿Tiene servicio de streaming de TV?
    'StreamingMovies': 'Streaming_Peliculas', # ¿Tiene servicio de streaming de películas?
    'Contract': 'Tipo_Contrato', # Tipo de contrato
    'PaperlessBilling': 'Facturacion_Sin_Papel', # Facturación sin papel
    'PaymentMethod': 'Metodo_Pago', # Método de pago
    'Charges.Monthly': 'Cargos_Mensuales', # Cargos mensuales en USD
    'Charges.Total': 'Cargos_Totales', # Cargos totales en USD
    # 'Cuentas.Diarias' ya está bien, la dejamos tal cual o la incluimos si queremos renombrar
    'Cuentas.Diarias': 'Cuentas_Diarias' # Por si quieres especificar
    }

# %%
df_M.rename(columns=nuevos_nombres, inplace=True)

# %%
df_M
# Out:
#       ID_Cliente Abandono_Servicio  Genero  Ciudadano_Senior  Tiene_Pareja  \
# 0     0002-ORFBO                No  Female                 0             1
# 1     0003-MKNFE                No    Male                 0             0
# 2     0004-TLHLJ               Yes    Male                 0             0
# 3     0011-IGKFF               Yes    Male                 1             1
# 4     0013-EXCHZ               Yes  Female                 1             1
# ...          ...               ...     ...               ...           ...
# 7262  9987-LUTYD                No  Female                 0             0
# 7263  9992-RRAMN               Yes    Male                 0             1
# 7264  9992-UJOEL                No    Male                 0             0
# 7265  9993-LHIEB                No    Male                 0             1
# 7266  9995-HOTOH                No    Male                 0             1
#
#       Tiene_Dependientes  Antiguedad_Meses  Servicio_Telefono  \
# ...

# %%
df_M.columns.tolist()
# Out:
# ['ID_Cliente',
#  'Abandono_Servicio',
#  'Genero',
#  'Ciudadano_Senior',
#  'Tiene_Pareja',
#  'Tiene_Dependientes',
#  'Antiguedad_Meses',
#  'Servicio_Telefono',
#  'Multiples_Lineas',
#  'Tipo_Servicio_Internet',
#  'Seguridad_Online',
#  'Copia_Seguridad_Online',
#  'Proteccion_Dispositivo',
#  'Soporte_Tecnico',
#  'Streaming_TV',
#  'Streaming_Peliculas',
#  'Tipo_Contrato',
#  'Facturacion_Sin_Papel',
#  'Metodo_Pago',
#  'Cargos_Mensuales',
#  'Cargos_Totales',
#  'Cuentas_Diarias']

# %%
df_M.shape
# Out:
# (7267, 22)

# %% [markdown]
# ##Informacion Duplicada

# %%
df_M.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##Valores Faltantes

# %%
df_M.isnull().sum()
# Out:
# ID_Cliente                  0
# Abandono_Servicio         224
# Genero                      0
# Ciudadano_Senior            0
# Tiene_Pareja                0
# Tiene_Dependientes          0
# Antiguedad_Meses            0
# Servicio_Telefono           0
# Multiples_Lineas            0
# Tipo_Servicio_Internet      0
# Seguridad_Online            0
# Copia_Seguridad_Online      0
# Proteccion_Dispositivo      0
# Soporte_Tecnico             0
# Streaming_TV                0
# Streaming_Peliculas         0
# Tipo_Contrato               0
# Facturacion_Sin_Papel       0
# Metodo_Pago                 0
# Cargos_Mensuales            0
# Cargos_Totales             11
# Cuentas_Diarias             0
# dtype: int64

# %%
df_M.isnull().sum().sum()
# Out:
# np.int64(235)

# %%
df_M.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID_Cliente              7267 non-null   object
#  1   Abandono_Servicio       7043 non-null   object
#  2   Genero                  7267 non-null   object
#  3   Ciudadano_Senior        7267 non-null   int64
#  4   Tiene_Pareja            7267 non-null   int64
#  5   Tiene_Dependientes      7267 non-null   int64
#  6   Antiguedad_Meses        7267 non-null   int64
#  7   Servicio_Telefono       7267 non-null   int64
#  8   Multiples_Lineas        7267 non-null   object
#  9   Tipo_Servicio_Internet  7267 non-null   object
#  10  Seguridad_Online        7267 non-null   object
#  11  Copia_Seguridad_Online  7267 non-null   object
#  12  Proteccion_Dispositivo  7267 non-null   object
#  13  Soporte_Tecnico         7267 non-null   object
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
df_M.head()
# Out:
#    ID_Cliente Abandono_Servicio  Genero  Ciudadano_Senior  Tiene_Pareja  \
# 0  0002-ORFBO                No  Female                 0             1
# 1  0003-MKNFE                No    Male                 0             0
# 2  0004-TLHLJ               Yes    Male                 0             0
# 3  0011-IGKFF               Yes    Male                 1             1
# 4  0013-EXCHZ               Yes  Female                 1             1
#
#    Tiene_Dependientes  Antiguedad_Meses  Servicio_Telefono Multiples_Lineas  \
# 0                   1                 9                  1               No
# 1                   0                 9                  1              Yes
# 2                   0                 4                  1               No
# 3                   0                13                  1               No
# 4                   0                 3                  1               No
#
#   Tipo_Servicio_Internet  ... Proteccion_Dispositivo Soporte_Tecnico  \
# ...

# %%
df_M.describe()
# Out:
#        Ciudadano_Senior  Tiene_Pareja  Tiene_Dependientes  Antiguedad_Meses  \
# count       7267.000000   7267.000000         7267.000000       7267.000000
# mean           0.162653      0.484106            0.300124         32.346498
# std            0.369074      0.499782            0.458343         24.571773
# min            0.000000      0.000000            0.000000          0.000000
# 25%            0.000000      0.000000            0.000000          9.000000
# 50%            0.000000      0.000000            0.000000         29.000000
# 75%            0.000000      1.000000            1.000000         55.000000
# max            1.000000      1.000000            1.000000         72.000000
#
#        Servicio_Telefono  Facturacion_Sin_Papel  Cargos_Mensuales  \
# count        7267.000000            7267.000000       7267.000000
# mean            0.902711               0.593230         64.720098
# std             0.296371               0.491265         30.129572
# ...

# %% [markdown]
# Distribución de evasión

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Abandono_Servicio', data=df_M)
plt.title('Distribución de Abandono de Servicio')
plt.xlabel('Abandono de Servicio (0=No, 1=Sí)')
plt.ylabel('Número de Clientes')
plt.xticks([0, 1], ['No Abandona', 'Abandona'])
plt.show()

# %% [markdown]
# (Distribución de Abandono de Servicio - Barras): Muestra el conteo absoluto de clientes que "No Abandona" y "Abandona". Es evidente que el número de clientes que "No Abandona" es significativamente mayor que el de clientes que "Abandona".

# %%
# O en porcentajes (Pie Chart)
plt.figure(figsize=(6, 6))
df_M['Abandono_Servicio'].value_counts(normalize=True).plot.pie(autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Porcentaje de Abandono de Servicio')
plt.ylabel('') # Eliminar etiqueta 'y' para el pie chart
plt.show()

# %% [markdown]
# (Porcentaje de Abandono de Servicio - Pastel): Cuantifica la proporción de cada categoría.
# * 73.5% No Abandona: La gran mayoría de los clientes permanece.
#
# * 26.5% Abandona: Una tasa de abandono de casi el 27% es considerablemente alta para una empresa de telecomunicaciones y justifica plenamente el proyecto de "Churn de Clientes".

# %% [markdown]
# Insight: La empresa enfrenta un problema de abandono significativo, con aproximadamente uno de cada cuatro clientes cancelando su servicio.

# %%
# Ejemplo: Abandono por Antigüedad_Meses (Histograma)
plt.figure(figsize=(10, 6))
sns.histplot(data=df_M, x='Antiguedad_Meses', hue='Abandono_Servicio', multiple='stack', bins=30)
plt.title('Distribución de Antigüedad por Abandono de Servicio')
plt.xlabel('Antigüedad en Meses')
plt.ylabel('Número de Clientes')
plt.legend(title='Abandono', labels=['No', 'Sí'])
plt.show()

# %% [markdown]
# Distribución de Antigüedad por Abandono de Servicio
#
# * Clientes de Baja Antigüedad: La mayor proporción de abandonos (Sí, color naranja) se concentra en los primeros meses de servicio (0-5 meses). Esto es un insight muy fuerte: los clientes recién llegados son los más propensos a irse.
#
# * Clientes de Alta Antigüedad: A medida que la antigüedad aumenta, la proporción de abandonos disminuye notablemente. Los clientes con 70 o más meses de antigüedad muestran una tasa de abandono muy baja, lo que indica lealtad.

# %% [markdown]
# Insight: La antigüedad del cliente es un predictor extremadamente potente del abandono. Los primeros meses son críticos para la retención. Se deberían enfocar esfuerzos y programas de "onboarding" (integración) y retención específicos para los clientes nuevos.

# %% [markdown]
# ##Conteo de evasión por variables numéricas

# %%
# Ejemplo: Abandono por Cargos_Mensuales_USD (Box Plot)
plt.figure(figsize=(8, 6))
sns.boxplot(x='Abandono_Servicio', y='Cargos_Mensuales', data=df_M)
plt.title('Cargos Mensuales por Estado de Abandono')
plt.xlabel('Abandono de Servicio (0=No, 1=Sí)')
plt.ylabel('Cargos Mensuales (USD)')
plt.xticks([0, 1], ['No Abandona', 'Abandona'])
plt.show()

# %% [markdown]
# (Cargos Mensuales por Estado de Abandono - Boxplot):
# * No Abandona: La mediana de los cargos mensuales se sitúa alrededor de $65-70.
#
# * Abandona: La mediana de los cargos mensuales es significativamente más alta, alrededor de $85-90.
#
# * Las cajas (IQR) también muestran que los clientes que abandonan tienen un rango de cargos mensuales generalmente más elevado.

# %%
# Solo si los datos de Charges.Total estuvieran en el ejemplo, aquí usamos Cargos_Mensuales_USD
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df_M, x='Cargos_Mensuales', hue='Abandono_Servicio', fill=True, common_norm=False)
plt.title('Densidad de Cargos Mensuales por Abandono de Servicio')
plt.xlabel('Cargos Mensuales (USD)')
plt.ylabel('Densidad')
plt.legend(title='Abandono', labels=['No', 'Sí'])
plt.show()

# %% [markdown]
# (Densidad de Cargos Mensuales por Abandono de Servicio - KDE Plot):
#
# * La curva de densidad para "No Abandona" (azul) muestra dos picos, uno alrededor de 20 a 30 dollares (probablemente planes básicos) y otro alrededor de $60-70.
#
# * La curva de densidad para "Sí Abandona" (naranja) tiene su pico principal claramente desplazado hacia valores más altos, alrededor de $70-100.
#
# * Hay una superposición, pero la tendencia es clara: los clientes con cargos mensuales más altos son más propensos a abandonar.

# %% [markdown]
# Insight: Los Cargos_Mensuales son un factor crítico. Los clientes con facturas mensuales más elevadas son los que tienen mayor propensión al abandono. Esto podría indicar problemas de percepción de valor, precios poco competitivos o insatisfacción con el servicio que justifique el costo. Se deben analizar los paquetes de servicios y precios asociados a estos cargos altos.

# %%
plt.figure(figsize=(10, 6)) # Crea una nueva figura para este gráfico
sns.histplot(data=df_M, x='Cargos_Totales', hue='Abandono_Servicio',
             multiple='stack', bins=40, kde=True, palette='coolwarm')
plt.title('Histograma de Cargos Totales por Estado de Abandono')
plt.xlabel('Cargos Totales (USD)')
plt.ylabel('Número de Clientes')
plt.legend(title='Abandono', labels=['No Abandona', 'Abandona'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8, 7))

# La corrección: Asignar 'Abandono_Servicio' (la variable del eje x) a 'hue' y luego ocultar la leyenda.
sns.boxplot(x='Abandono_Servicio', y='Cargos_Totales', hue='Abandono_Servicio',
            data=df_M, palette='viridis', legend=False)

plt.title('Box Plot de Cargos Totales por Estado de Abandono')
plt.xlabel('Abandono de Servicio (0 = No Abandona, 1 = Abandona)')
plt.ylabel('Cargos Totales (USD)')
plt.xticks([0, 1], ['No Abandona', 'Abandona'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6)) # Crea una nueva figura para este gráfico
sns.kdeplot(data=df_M, x='Cargos_Totales', hue='Abandono_Servicio',
            fill=True, common_norm=False, palette='mako')
plt.title('Densidad de Cargos Totales por Estado de Abandono')
plt.xlabel('Cargos Totales (USD)')
plt.ylabel('Densidad')
plt.legend(title='Abandono', labels=['No Abandona', 'Abandona'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6)) # Crea una nueva figura para este gráfico
sns.histplot(data=df_M, x='Antiguedad_Meses', hue='Abandono_Servicio',
             multiple='stack', bins=30, kde=True, palette='coolwarm')
plt.title('Histograma de Antigüedad por Estado de Abandono')
plt.xlabel('Antigüedad en Meses')
plt.ylabel('Número de Clientes')
plt.legend(title='Abandono', labels=['No Abandona', 'Abandona'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8, 7)) # Crea una nueva figura para este gráfico
sns.boxplot(x='Abandono_Servicio', y='Antiguedad_Meses', hue='Abandono_Servicio',
            data=df_M, palette='viridis', legend=False) # Corrección de la advertencia aquí
plt.title('Box Plot de Antigüedad en Meses por Estado de Abandono')
plt.xlabel('Abandono de Servicio (0 = No Abandona, 1 = Abandona)')
plt.ylabel('Antigüedad en Meses')
plt.xticks([0, 1], ['No Abandona', 'Abandona']) # Etiquetas más descriptivas
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6)) # Crea una nueva figura para este gráfico
sns.kdeplot(data=df_M, x='Antiguedad_Meses', hue='Abandono_Servicio',
            fill=True, common_norm=False, palette='mako')
plt.title('Densidad de Antigüedad por Estado de Abandono')
plt.xlabel('Antigüedad en Meses')
plt.ylabel('Densidad')
plt.legend(title='Abandono', labels=['No Abandona', 'Abandona'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##Recuento de evasión por variables categóricas

# %%
conteo_abandono_genero = df_M.groupby('Genero')['Abandono_Servicio'].value_counts().unstack(fill_value=0)

# %%
conteo_abandono_genero
# Out:
# Abandono_Servicio    No  Yes
# Genero
# Female             2549  939
# Male               2625  930

# %%
conteo_abandono_genero.columns
# Out:
# Index(['No', 'Yes'], dtype='object', name='Abandono_Servicio')

# %%
tasa_abandono_genero = conteo_abandono_genero.apply(lambda x: x['Yes'] / (x['No'] + x['Yes']) * 100, axis=1)

# %%
tasa_abandono_genero
# Out:
# Genero
# Female    26.920872
# Male      26.160338
# dtype: float64

# %%
# Preparar el DataFrame para el gráfico de barras de tasas (como se corrigió previamente)
plot_df_tasa = tasa_abandono_genero.reset_index(name='Tasa_Abandono')

# --- Crear la figura y los dos subgráficos ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6)) # 1 fila, 2 columnas, tamaño total de la figura

# --- Gráfico 1: Tasa de Abandono por Género (%) ---
sns.barplot(x='Genero', y='Tasa_Abandono', hue='Genero', data=plot_df_tasa, palette='viridis', legend=False, ax=axes[0])
axes[0].set_title('Tasa de Abandono de Servicio por Género (%)')
axes[0].set_xlabel('Género')
axes[0].set_ylabel('Porcentaje de Abandono (%)')
axes[0].set_ylim(0, 100)
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Añadir los valores en la parte superior de las barras
for index, value in enumerate(plot_df_tasa['Tasa_Abandono']):
    axes[0].text(index, value + 2, f'{value:.2f}%', ha='center', va='bottom', fontsize=10)

# --- Gráfico 2: Número de Clientes por Género y Estado de Abandono ---
sns.countplot(x='Genero', hue='Abandono_Servicio', data=df_M, palette='pastel', ax=axes[1])
axes[1].set_title('Número de Clientes por Género y Estado de Abandono')
axes[1].set_xlabel('Género')
axes[1].set_ylabel('Número de Clientes')
axes[1].legend(title='Abandono', labels=['No Abandona', 'Abandona'])
axes[1].grid(axis='y', linestyle='--', alpha=0.7)


plt.tight_layout() # Ajusta automáticamente los parámetros del subgráfico para un diseño ajustado
plt.show()

# %%
conteo_abandono_contrato = df_M.groupby('Tipo_Contrato')['Abandono_Servicio'].value_counts().unstack(fill_value=0)

# %%
conteo_abandono_contrato
# Out:
# Abandono_Servicio    No   Yes
# Tipo_Contrato
# Month-to-month     2220  1655
# One year           1307   166
# Two year           1647    48

# %%
tasa_abandono_contrato = conteo_abandono_contrato.apply(lambda x: x['Yes'] / (x['No'] + x['Yes']) * 100, axis=1)

# %%
tasa_abandono_contrato
# Out:
# Tipo_Contrato
# Month-to-month    42.709677
# One year          11.269518
# Two year           2.831858
# dtype: float64

# %%
# Preparar el DataFrame para el gráfico de barras de tasas
plot_df_tasa_contrato = tasa_abandono_contrato.reset_index(name='Tasa_Abandono')

# --- Crear la figura y los dos subgráficos ---
fig, axes = plt.subplots(1, 2, figsize=(18, 7)) # 1 fila, 2 columnas, ajusta el tamaño

# --- Gráfico 1: Tasa de Abandono por Tipo de Contrato (%) ---
# Asegúrate de ordenar las categorías del contrato si lo deseas (opcional)
# Por ejemplo: plot_df_tasa_contrato['Tipo_Contrato'] = pd.Categorical(
#     plot_df_tasa_contrato['Tipo_Contrato'],
#     categories=['Month-to-month', 'One year', 'Two year'],
#     ordered=True
# )
# plot_df_tasa_contrato = plot_df_tasa_contrato.sort_values('Tipo_Contrato')


sns.barplot(x='Tipo_Contrato', y='Tasa_Abandono', hue='Tipo_Contrato',
            data=plot_df_tasa_contrato, palette='viridis', legend=False, ax=axes[0])
axes[0].set_title('Tasa de Abandono de Servicio por Tipo de Contrato (%)')
axes[0].set_xlabel('Tipo de Contrato')
axes[0].set_ylabel('Porcentaje de Abandono (%)')
axes[0].set_ylim(0, 100) # Asegurar que el eje Y vaya de 0 a 100
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Añadir los valores en la parte superior de las barras
for index, value in enumerate(plot_df_tasa_contrato['Tasa_Abandono']):
    axes[0].text(index, value + 2, f'{value:.2f}%', ha='center', va='bottom', fontsize=10)

# --- Gráfico 2: Número de Clientes por Tipo de Contrato y Estado de Abandono ---
sns.countplot(x='Tipo_Contrato', hue='Abandono_Servicio', data=df_M, palette='pastel', ax=axes[1])
axes[1].set_title('Número de Clientes por Tipo de Contrato y Estado de Abandono')
axes[1].set_xlabel('Tipo de Contrato')
axes[1].set_ylabel('Número de Clientes')
axes[1].legend(title='Abandono', labels=['No Abandona', 'Abandona'])
axes[1].grid(axis='y', linestyle='--', alpha=0.7)


plt.tight_layout() # Ajusta automáticamente los parámetros del subgráfico
plt.show()

# %%
conteo_abandono_pago = df_M.groupby('Metodo_Pago')['Abandono_Servicio'].value_counts().unstack(fill_value=0)

# %%
conteo_abandono_pago
# Out:
# Abandono_Servicio            No   Yes
# Metodo_Pago
# Bank transfer (automatic)  1286   258
# Credit card (automatic)    1290   232
# Electronic check           1294  1071
# Mailed check               1304   308

# %%
tasa_abandono_pago = conteo_abandono_pago.apply(lambda x: x['Yes'] / (x['No'] + x['Yes']) * 100, axis=1)

# %%
tasa_abandono_pago
# Out:
# Metodo_Pago
# Bank transfer (automatic)    16.709845
# Credit card (automatic)      15.243101
# Electronic check             45.285412
# Mailed check                 19.106700
# dtype: float64

# %%
# Preparar el DataFrame para el gráfico de barras de tasas
plot_df_tasa_pago = tasa_abandono_pago.reset_index(name='Tasa_Abandono')

# Ordenar las categorías para que el gráfico sea más legible (opcional, pero recomendado)
orden_metodo_pago = [
    'Electronic check',
    'Mailed check',
    'Bank transfer (automatic)',
    'Credit card (automatic)'
]
plot_df_tasa_pago['Metodo_Pago'] = pd.Categorical(
    plot_df_tasa_pago['Metodo_Pago'],
    categories=orden_metodo_pago,
    ordered=True
)
plot_df_tasa_pago = plot_df_tasa_pago.sort_values('Metodo_Pago')

# --- Crear la figura y los dos subgráficos ---
fig, axes = plt.subplots(1, 2, figsize=(20, 7)) # 1 fila, 2 columnas, ajusta el tamaño

# --- Gráfico 1: Tasa de Abandono por Método de Pago (%) ---
sns.barplot(x='Metodo_Pago', y='Tasa_Abandono', hue='Metodo_Pago',
            data=plot_df_tasa_pago, palette='coolwarm', legend=False, ax=axes[0])
axes[0].set_title('Tasa de Abandono de Servicio por Método de Pago (%)')
axes[0].set_xlabel('Método de Pago')
axes[0].set_ylabel('Porcentaje de Abandono (%)')
axes[0].set_ylim(0, 100) # Asegurar que el eje Y vaya de 0 a 100
# Eliminar el argumento 'ha' que no es reconocido por tick_params
axes[0].tick_params(axis='x', rotation=45)
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Añadir los valores en la parte superior de las barras
for index, value in enumerate(plot_df_tasa_pago['Tasa_Abandono']):
    axes[0].text(index, value + 2, f'{value:.2f}%', ha='center', va='bottom', fontsize=10)

# --- Gráfico 2: Número de Clientes por Método de Pago y Estado de Abandono ---
sns.countplot(x='Metodo_Pago', hue='Abandono_Servicio', data=df_M, palette='pastel', ax=axes[1],
              order=orden_metodo_pago) # Usar el mismo orden para consistencia
axes[1].set_title('Número de Clientes por Método de Pago y Estado de Abandono')
axes[1].set_xlabel('Método de Pago')
axes[1].set_ylabel('Número de Clientes')
axes[1].legend(title='Abandono', labels=['No Abandona', 'Abandona'])
# Eliminar el argumento 'ha' que no es reconocido por tick_params
axes[1].tick_params(axis='x', rotation=45)
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout() # Ajusta automáticamente los parámetros del subgráfico
plt.show()

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ##Resumen Ejecutivo

# %% [markdown]
# Telecom X enfrenta una preocupante tasa de abandono de clientes, con aproximadamente el 26.5% de su base de clientes cancelando sus servicios. Este informe detalla los hallazgos clave de un análisis exploratorio de datos, revelando que la antigüedad del cliente y los cargos mensuales son los predictores más significativos del abandono. Los clientes con menor antigüedad y aquellos con cargos mensuales más elevados son particularmente propensos a irse. Si bien "Cuentas Diarias" también muestra una leve diferencia, su impacto es menos pronunciado. Estos insights subrayan la necesidad de estrategias de retención focalizadas y proactivas para mitigar la pérdida de clientes.

# %% [markdown]
# ## Metodología

# %% [markdown]
# Se realizó un Análisis Exploratorio de Datos (EDA) sobre el DataFrame df_M de 7267 filas y 22 columnas. La metodología incluyó:
#
# * Limpieza de Datos: Identificación y tratamiento de valores nulos.
#
# * Análisis Descriptivo: Resumen estadístico y distribución de variables.
#
# * Visualizaciones Estratégicas: Creación de gráficos para identificar patrones y tendencias entre las características del cliente y el "Abandono_Servicio".

# %% [markdown]
# ##Hallazgos Clave Basados en Visualizaciones

# %% [markdown]
# ###Panorama General del Abandono de Servicio

# %% [markdown]
# * Distribución Absoluta (Referencia grafico: Distribución de  Abandono de Servicio): El gráfico de barras muestra claramente que la mayoría de los clientes permanece (No Abandona), mientras que una porción considerable sí abandona (Abandona).
# * Porcentaje de Abandono (Referencia grafico: Distribución de  Abandono de Servicio): La visualización circular confirma que el 26.5% de los clientes ha abandonado el servicio, mientras que el 73.5% ha permanecido. Esta proporción de abandono es elevada y justifica la urgencia de entender y mitigar este fenómeno.

# %% [markdown]
# Insight: El problema del churn es sustancial, con más de una cuarta parte de la base de clientes abandonando.

# %% [markdown]
# ###Impacto de la Antigüedad del Cliente en el Abandono

# %% [markdown]
# * Distribución de Antigüedad por Abandono (Referencia grafico: Distribución de Antigüedad por Abandono de Servicio): Este histograma apilado revela uno de los insights más críticos:
#
#  * Vulnerabilidad Temprana: La mayor concentración de abandonos (barras naranjas) ocurre en los primeros 5-10 meses de servicio. Los clientes recién llegados son los más propensos a cancelar.
#
#  * Lealtad con el Tiempo: A medida que la antigüedad del cliente aumenta (especialmente después de los 20-30 meses), la proporción de abandonos disminuye drásticamente, indicando una mayor lealtad por parte de los clientes de larga data.

# %% [markdown]
# Insight: La fase inicial de la relación con el cliente es la más crítica para la retención. La "antigüedad" es un predictor muy fuerte del abandono.

# %% [markdown]
# ###Influencia de los Cargos Mensuales en el Abandono

# %% [markdown]
# * Cargos Mensuales por Estado de Abandono (Referencia grafica: Cargos Mensuales por Estado de Abandono): El boxplot muestra que la mediana de los "Cargos_Mensuales" para los clientes que Abandona es notablemente más alta que para aquellos que No Abandona. Los clientes que se van tienden a tener facturas mensuales más elevadas.
#
# * Densidad de Cargos Mensuales por Abandono (Referencia grafica: Densidad de Cargos Mensuales por Abandono de Servicio): El gráfico de densidad refuerza esta observación. La distribución de los clientes que Abandona (naranja) muestra un pico de densidad significativamente desplazado hacia valores más altos de "Cargos_Mensuales" (aproximadamente entre 70 y 100 dólares), mientras que la distribución de los clientes que No Abandona (azul) tiene un pico más bajo y una dispersión más amplia, incluyendo muchos clientes con cargos reducidos.

# %% [markdown]
# Insight: Existe una fuerte correlación entre altos cargos mensuales y la propensión al abandono. Los clientes podrían percibir un valor insuficiente por el costo que pagan, o encontrar ofertas más competitivas en el mercado.

# %% [markdown]
# ###Cuentas Diarias Registradas y su Relación con el Abandono

# %% [markdown]
# * Cuentas Diarias por Estado de Abandono (Referencia grafica: Cuentas Diarias Registradas por Estado de Abandono): Aunque hay una ligera diferencia en las medianas (los que abandonan tienen una mediana marginalmente más alta de cuentas diarias), el solapamiento de los rangos intercuartílicos es considerable.
#
# * Densidad de Cuentas Diarias por Abandono (Referencia grafica: Densidad de Cuentas Diarias por Estado de Abandono): Las distribuciones de densidad para ambos grupos (No Abandona y Abandona) son muy similares y se superponen en gran medida. Si bien los clientes que abandonan muestran una leve tendencia a tener más cuentas diarias, esta variable no se presenta como un factor determinante tan claro como la antigüedad o los cargos mensuales.

# %% [markdown]
# Insight: La variable "Cuentas_Diarias" no parece ser un predictor primario y aislado del abandono. Su impacto, si lo hay, podría ser sutil o estar en interacción con otras variables.

# %% [markdown]
# ##Conclusiones y Recomendaciones Preliminares

# %% [markdown]
# Este análisis exploratorio ha desvelado patrones críticos en el comportamiento de abandono de los clientes de Telecom X:
#
# 1. Enfoque en la Retención Temprana: La baja antigüedad es el predictor más fuerte de abandono. Es imperativo que Telecom X desarrolle e implemente programas de "onboarding" (integración) y engagement proactivos para los clientes en sus primeros 6-12 meses de servicio. Esto podría incluir llamadas de seguimiento, ofertas personalizadas, soporte técnico prioritario o guías de uso para asegurar una experiencia inicial positiva.
#
# 2. Reevaluación de la Estrategia de Precios y Valor: Los altos cargos mensuales están directamente relacionados con una mayor tasa de abandono. Telecom X debe:
#
#  * Auditar los paquetes de servicio de alto costo: Entender si el valor percibido por el cliente justifica los cargos.
#
#  * Considerar la introducción de planes más flexibles o económicos para ciertos segmentos.
#
#  * Ofrecer incentivos o beneficios adicionales a los clientes con cargos elevados para aumentar su percepción de valor.
#
# 3. Investigación Adicional de Servicios: Aunque no se mostraron gráficos aquí, es crucial investigar cómo otros servicios (tipo de internet, seguridad online, soporte técnico, tipo de contrato) influyen en el abandono, como se sugirió en el plan EDA inicial. La tendencia de los clientes con fibra óptica a abandonar más que los de DSL o la relación con servicios adicionales es un área clave.
