# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
url_json = 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'

# %%
df = pd.read_json(url_json)

# %%
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %%
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
df.tail()
# Out:
#       customerID Churn                                           customer  \
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...

# %%
df.sample(5)
# Out:
#       customerID Churn                                           customer  \
# 4278  5884-FBCTL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1887  2674-MIAHT    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4876  6670-MFRPK    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 5701  7789-CRUVC    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 2606  3638-WEABW    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# 4278  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 1887  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 4876  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 5701  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2606  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 4278  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 1887  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4876  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5701  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 2606  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 4278  {'Contract': 'Two year', 'PaperlessBilling': '...
# 1887  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4876  {'Contract': 'Two year', 'PaperlessBilling': '...
# 5701  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2606  {'Contract': 'Two year', 'PaperlessBilling': '...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df.shape
# Out:
# (7267, 6)

# %%
df.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7267, step=1)

# %%
df.isnull().sum()
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
df.isnull()
# Out:
#       customerID  Churn  customer  phone  internet  account
# 0          False  False     False  False     False    False
# 1          False  False     False  False     False    False
# 2          False  False     False  False     False    False
# 3          False  False     False  False     False    False
# 4          False  False     False  False     False    False
# ...          ...    ...       ...    ...       ...      ...
# 7262       False  False     False  False     False    False
# 7263       False  False     False  False     False    False
# 7264       False  False     False  False     False    False
# 7265       False  False     False  False     False    False
# 7266       False  False     False  False     False    False
#
# [7267 rows x 6 columns]

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ##Nomalizando los datos JSON

# %% [markdown]
# ###Customer

# %%
df_customer_N = pd.json_normalize(df['customer'])

# %%
df_customer_N
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
df_customer_N.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure
# 0  Female              0     Yes        Yes       9
# 1    Male              0      No         No       9
# 2    Male              0      No         No       4
# 3    Male              1     Yes         No      13
# 4  Female              1     Yes         No       3

# %%
df_customer_N.tail()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63

# %%
df_customer_N.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 1080    Male              0     Yes        Yes      52
# 640   Female              0      No         No      64
# 6053    Male              0      No         No       1
# 52    Female              0     Yes        Yes      39
# 5671  Female              1      No        Yes      30

# %%
df_customer_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
df_customer_N.shape
# Out:
# (7267, 5)

# %%
df_customer_N.index
# Out:
# RangeIndex(start=0, stop=7267, step=1)

# %%
df_customer_N.isnull()
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure
# 0      False          False    False       False   False
# 1      False          False    False       False   False
# 2      False          False    False       False   False
# 3      False          False    False       False   False
# 4      False          False    False       False   False
# ...      ...            ...      ...         ...     ...
# 7262   False          False    False       False   False
# 7263   False          False    False       False   False
# 7264   False          False    False       False   False
# 7265   False          False    False       False   False
# 7266   False          False    False       False   False
#
# [7267 rows x 5 columns]

# %%
df_customer_N.isnull().sum()
# Out:
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# tenure           0
# dtype: int64

# %%
df_customer_N.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure'], dtype='object')

# %% [markdown]
# ###Phone

# %%
df_phone_N = pd.json_normalize(df['phone'])

# %%
df_phone_N
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
df_phone_N.head()
# Out:
#   PhoneService MultipleLines
# 0          Yes            No
# 1          Yes           Yes
# 2          Yes            No
# 3          Yes            No
# 4          Yes            No

# %%
df_phone_N.tail()
# Out:
#      PhoneService     MultipleLines
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service

# %%
df_phone_N.sample(5)
# Out:
#      PhoneService     MultipleLines
# 2986           No  No phone service
# 772           Yes               Yes
# 4510          Yes               Yes
# 1698           No  No phone service
# 4357          Yes               Yes

# %%
df_phone_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
df_phone_N.shape
# Out:
# (7267, 2)

# %%
df_phone_N.index
# Out:
# RangeIndex(start=0, stop=7267, step=1)

# %%
df_phone_N.isnull()
# Out:
#       PhoneService  MultipleLines
# 0            False          False
# 1            False          False
# 2            False          False
# 3            False          False
# 4            False          False
# ...            ...            ...
# 7262         False          False
# 7263         False          False
# 7264         False          False
# 7265         False          False
# 7266         False          False
#
# [7267 rows x 2 columns]

# %%
df_phone_N.isnull().sum()
# Out:
# PhoneService     0
# MultipleLines    0
# dtype: int64

# %%
df_phone_N.columns
# Out:
# Index(['PhoneService', 'MultipleLines'], dtype='object')

# %% [markdown]
# ###Internet

# %%
df_internet_N = pd.json_normalize(df['internet'])

# %%
df_internet_N
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# 0            Yes              No
# 1             No             Yes
# 2             No              No
# 3            Yes             Yes
# 4            Yes              No
# ...          ...             ...
# 7262          No              No
# 7263          No             Yes
# 7264          No              No
# 7265          No             Yes
# 7266         Yes             Yes
#
# [7267 rows x 7 columns]

# %%
df_internet_N.head()
# Out:
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No         Yes
# 1             DSL             No           No               No          No
# 2     Fiber optic             No           No              Yes          No
# 3     Fiber optic             No          Yes              Yes          No
# 4     Fiber optic             No           No               No         Yes
#
#   StreamingTV StreamingMovies
# 0         Yes              No
# 1          No             Yes
# 2          No              No
# 3         Yes             Yes
# 4         Yes              No

# %%
df_internet_N.tail()
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# 7262          No              No
# 7263          No             Yes
# 7264          No              No
# 7265          No             Yes
# 7266         Yes             Yes

# %%
df_internet_N.sample(5)
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 5631             DSL             No          Yes               No         Yes
# 1077             DSL            Yes          Yes               No          No
# 4710     Fiber optic            Yes          Yes               No          No
# 3191     Fiber optic             No           No               No         Yes
# 4584     Fiber optic             No           No               No         Yes
#
#      StreamingTV StreamingMovies
# 5631         Yes              No
# 1077         Yes             Yes
# 4710          No              No
# 3191         Yes             Yes
# 4584         Yes              No

# %%
df_internet_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB

# %%
df_internet_N.shape
# Out:
# (7267, 7)

# %%
df_internet_N.index
# Out:
# RangeIndex(start=0, stop=7267, step=1)

# %%
df_internet_N.isnull()
# Out:
#       InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 0               False           False         False             False
# 1               False           False         False             False
# 2               False           False         False             False
# 3               False           False         False             False
# 4               False           False         False             False
# ...               ...             ...           ...               ...
# 7262            False           False         False             False
# 7263            False           False         False             False
# 7264            False           False         False             False
# 7265            False           False         False             False
# 7266            False           False         False             False
#
#       TechSupport  StreamingTV  StreamingMovies
# 0           False        False            False
# 1           False        False            False
# 2           False        False            False
# 3           False        False            False
# 4           False        False            False
# ...           ...          ...              ...
# 7262        False        False            False
# 7263        False        False            False
# 7264        False        False            False
# 7265        False        False            False
# 7266        False        False            False
#
# [7267 rows x 7 columns]

# %%
df_internet_N.isnull().sum()
# Out:
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %%
df_internet_N.columns
# Out:
# Index(['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies'],
#       dtype='object')

# %% [markdown]
# ###Account

# %%
df_account_N = pd.json_normalize(df['account'])

# %%
df_account_N
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# 3          1237.85
# 4            267.4
# ...            ...
# 7262         742.9
# 7263        1873.7
# 7264         92.75
# 7265       4627.65
# 7266        3707.6
#
# [7267 rows x 5 columns]

# %%
df_account_N.head()
# Out:
#          Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0        One year              Yes      Mailed check             65.6
# 1  Month-to-month               No      Mailed check             59.9
# 2  Month-to-month              Yes  Electronic check             73.9
# 3  Month-to-month              Yes  Electronic check             98.0
# 4  Month-to-month              Yes      Mailed check             83.9
#
#   Charges.Total
# 0         593.3
# 1         542.4
# 2        280.85
# 3       1237.85
# 4         267.4

# %%
df_account_N.tail()
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 7262         742.9
# 7263        1873.7
# 7264         92.75
# 7265       4627.65
# 7266        3707.6

# %%
df_account_N.sample(5)
# Out:
#             Contract PaperlessBilling              PaymentMethod  \
# 2118  Month-to-month              Yes    Credit card (automatic)
# 5754        Two year               No    Credit card (automatic)
# 6632        One year               No           Electronic check
# 5265  Month-to-month               No               Mailed check
# 3064        Two year               No  Bank transfer (automatic)
#
#       Charges.Monthly Charges.Total
# 2118            91.95       3301.05
# 5754            64.45          4720
# 6632            96.10       6001.45
# 5265           103.85          2215
# 3064            19.95       1322.85

# %%
df_account_N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7267 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 284.0+ KB

# %%
df_account_N.shape
# Out:
# (7267, 5)

# %%
df_account_N.index
# Out:
# RangeIndex(start=0, stop=7267, step=1)

# %%
df_account_N.isnull()
# Out:
#       Contract  PaperlessBilling  PaymentMethod  Charges.Monthly  \
# 0        False             False          False            False
# 1        False             False          False            False
# 2        False             False          False            False
# 3        False             False          False            False
# 4        False             False          False            False
# ...        ...               ...            ...              ...
# 7262     False             False          False            False
# 7263     False             False          False            False
# 7264     False             False          False            False
# 7265     False             False          False            False
# 7266     False             False          False            False
#
#       Charges.Total
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 7262          False
# 7263          False
# 7264          False
# 7265          False
# 7266          False
#
# [7267 rows x 5 columns]

# %%
df_account_N.isnull().sum()
# Out:
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
df_account_N.columns
# Out:
# Index(['Contract', 'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %% [markdown]
# ##Churn

# %%
df[['customerID', 'Churn']]
# Out:
#       customerID Churn
# 0     0002-ORFBO    No
# 1     0003-MKNFE    No
# 2     0004-TLHLJ   Yes
# 3     0011-IGKFF   Yes
# 4     0013-EXCHZ   Yes
# ...          ...   ...
# 7262  9987-LUTYD    No
# 7263  9992-RRAMN   Yes
# 7264  9992-UJOEL    No
# 7265  9993-LHIEB    No
# 7266  9995-HOTOH    No
#
# [7267 rows x 2 columns]

# %%
df_ID_Churn = df[['customerID', 'Churn']]

# %%
df_ID_Churn.head()
# Out:
#    customerID Churn
# 0  0002-ORFBO    No
# 1  0003-MKNFE    No
# 2  0004-TLHLJ   Yes
# 3  0011-IGKFF   Yes
# 4  0013-EXCHZ   Yes

# %%
df_ID_Churn.tail()
# Out:
#       customerID Churn
# 7262  9987-LUTYD    No
# 7263  9992-RRAMN   Yes
# 7264  9992-UJOEL    No
# 7265  9993-LHIEB    No
# 7266  9995-HOTOH    No

# %%
df_ID_Churn.sample(5)
# Out:
#       customerID Churn
# 2560  3571-DPYUH    No
# 1818  2589-AYCRP    No
# 3014  4188-PCPIG    No
# 7101  9777-WJJPR    No
# 1555  2225-ZRGSG   Yes

# %%
df_ID_Churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
df_ID_Churn.shape
# Out:
# (7267, 2)

# %%
df_ID_Churn.index
# Out:
# RangeIndex(start=0, stop=7267, step=1)

# %%
df_ID_Churn.isnull()
# Out:
#       customerID  Churn
# 0          False  False
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False
# ...          ...    ...
# 7262       False  False
# 7263       False  False
# 7264       False  False
# 7265       False  False
# 7266       False  False
#
# [7267 rows x 2 columns]

# %%
df_ID_Churn.isnull().sum()
# Out:
# customerID    0
# Churn         0
# dtype: int64

# %%
df_ID_Churn.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df_ID_Churn.columns
# Out:
# Index(['customerID', 'Churn'], dtype='object')

# %% [markdown]
# Nota: `Churn`: si el cliente dejó o no la empresa

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
